# %% [markdown]
# <b>INSTITUTO FEDERAL DE GOIÁS<br/>
# PÓS-GRADUAÇÃO EM INTELIGÊNCIA ARTIFICIAL APLICADA<br/></b>
# Disciplina: Processamento de Linguagem Natural  <br/>
# Professor: Daniel Xavier de Sousa <br/>
# Alunos: Wagner Silva, Cleibson, Marcos Rodrigues
#
#
# ---

# %%
import pandas as pd
import numpy as np

from tqdm import tqdm

import nltk
nltk.download('stopwords')
nltk.download('punkt')
from nltk.stem import SnowballStemmer
from nltk.corpus import stopwords

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split, KFold

'''
confusion_matrix, 
roc_curve, 
auc, 
accuracy_score, 
log_loss, 
f1_score, 
recall_score, 
precision_score, 
classification_report, 
average_precision_score, 
precision_recall_curve, 
roc_curve, auc
'''

from sklearn.metrics import f1_score, accuracy_score

import tensorflow as tf
from tensorflow import keras
from keras.models import Sequential
from tensorflow.keras.layers import Embedding, Dense, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping

import matplotlib.pyplot as plt
import seaborn as sbn
# Out:
# [nltk_data] Downloading package stopwords to /home/marcos/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /home/marcos/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
df = pd.read_csv(f'../datasets/buscape_preprocessed.csv')

# %%
df.shape
# Out:
# (133438, 2)

# %%
df.head(3)
# Out:
#                                          review_text  rating
# 0  estou muito satisfeito o visor e melhor do que...       1
# 1  muito boa o que gostei preco o que nao gostei ...       1
# 2  rapida otima qualidade de impressao e facil de...       1

# %%
df = df[:10000]

# %%
df['rating'].value_counts()
# Out:
# rating
# 1    9086
# 0     914
# Name: count, dtype: int64

# %%
documents = df['review_text'].tolist()
labels = df['rating']

# %%
# Steamming
stemmer = SnowballStemmer("portuguese")

def custom_tokenizer(text):
    tokens = nltk.word_tokenize(text)
    stemmed_tokens = [stemmer.stem(token) for token in tokens]
    return stemmed_tokens

tfidf_vectorizer = TfidfVectorizer(
    # Steamming
    tokenizer=custom_tokenizer,
    # Removing stopwords
    stop_words=stopwords.words('portuguese'),
    ngram_range=(1,2),
    min_df=8,
    max_df=0.3,
    max_features=5000
)
#tfidf_vectorizer.get_feature_names_out()

# %%
tfidf_matrix = tfidf_vectorizer.fit_transform(documents)
# Out:
# /home/marcos/anaconda3/envs/test_env/lib/python3.10/site-packages/sklearn/feature_extraction/text.py:525: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   warnings.warn(
# /home/marcos/anaconda3/envs/test_env/lib/python3.10/site-packages/sklearn/feature_extraction/text.py:408: UserWarning: Your stop_words may be inconsistent with your preprocessing. Tokenizing the stop words generated tokens ['aquel', 'aquil', 'del', 'depo', 'estam', 'estav', 'estej', 'estev', 'estiv', 'estivéss', 'estáv', 'estã', 'fom', 'form', 'foss', 'fôr', 'fôss', 'haj', 'hav', 'houv', 'houvéss', 'hã', 'mesm', 'minh', 'muit', 'noss', 'nã', 'par', 'pel', 'quand', 'sej', 'serã', 'som', 'sã', 'tenh', 'ter', 'terã', 'tev', 'tinh', 'tiv', 'tivéss', 'tính', 'voc', 'éram'] not in stop_words.
#   warnings.warn(

# %%
label_encoder = LabelEncoder()
encoded_labels = label_encoder.fit_transform(labels)

# %%
X_train_documents, X_test_documents, y_train_labels, y_test_labels = train_test_split(tfidf_matrix, encoded_labels, test_size=0.2, random_state=42)

# %%
def begin_trainning(train_seq, input_shape, dropout, learning_rate, X_train_documents, y_train_labels):
    
    model = Sequential()
    model.add(Dense(24, activation='relu', input_shape=(input_shape,)))
    model.add(Dropout(dropout)),
    model.add(Dense(1, activation='sigmoid'))

    model.compile(optimizer=Adam(learning_rate=learning_rate), loss='binary_crossentropy', metrics=['acc'])
    
    k_folds = 2
    kfolds=KFold(n_splits=k_folds, shuffle=True, random_state=42)
    
    train_losses = []
    train_f1_scores = []
    train_accuracies = []
    
    val_losses = []
    val_f1_scores = []
    val_accuracies = []

    for fold, (train_idx, test_idx) in enumerate(kfolds.split(X_train_documents), start=1):
        print(f'fold --> {fold}')

        X_train, X_test = X_train_documents[train_idx], X_train_documents[test_idx]
        y_train, y_test = y_train_labels[train_idx], y_train_labels[test_idx]

        model_history = model.fit(
            X_train.toarray(),
            y_train,
            epochs=2,
            batch_size=32,
            callbacks=[EarlyStopping('loss', patience=3)],
            validation_data=(X_test.toarray(), y_test),
            verbose=0
        )
        
        train_loss = model_history.history['loss']
        train_losses.append(train_loss)
        
        train_pred = (model.predict(X_train.toarray()) > 0.5).astype(int)
        
        train_f1_sc = f1_score(y_train, train_pred)
        train_f1_scores.append(train_f1_sc)
        
        train_acc= accuracy_score(y_train, train_pred)
        train_accuracies.append(train_acc)
        
        # -----------------------------------------------------------------------------------
        
        val_loss = model_history.history['val_loss']
        val_losses.append(val_loss)
    
        val_pred = (model.predict(X_test.toarray()) > 0.5).astype(int)
        
        val_f1_sc = f1_score(y_test, val_pred)
        val_f1_scores.append(val_f1_sc)
        
        val_accuracy = accuracy_score(y_test, val_pred)
        val_accuracies.append(val_accuracy)
        
    print('--'*20)
    print(f'mean train losses: {np.mean(train_losses)}')
    print(f'mean train f1 scores: {np.mean(train_f1_scores)}')
    print(f'mean train accuracies: {np.mean(train_accuracies)}')
    print('--'*20)
    print(f'mean val losses: {np.mean(val_losses)}')
    print(f'mean val f1 scores: {np.mean(val_f1_scores)}')
    print(f'mean val accuracies: {np.mean(val_accuracies)}')
    print('--'*20)
    
    print('saving graphs...')
    plot_eval_train_test_graph(model_history, 'loss', train_seq)
    plot_eval_train_test_graph(model_history, 'acc', train_seq)
    print('finished saving graphs...')

# %%
def plot_eval_train_test_graph(history, metric, train_seq):
    
    train_arr = history.history[f'{metric}']
    val_arr = history.history[f'val_{metric}']
    
    epochs = range(1, len(train_arr) + 1)
    
    graph_path = f'./graphs/01_tfidf_mlp_v_2/train_test_{metric}/train_seq_{train_seq}_eval_train_test_{metric}.png'
    
    # Create a plot
    plt.figure(figsize=(10, 6))
    plt.plot(epochs, train_arr, 'b', label=f'Training {metric}')
    plt.plot(epochs, val_arr, 'r', label='Test Loss')

    # Labeling the plot
    plt.title(f'Train and Test {metric}')
    plt.xlabel('Epochs')
    plt.ylabel(f'{metric}')
    plt.legend()

    # Show the plot
    plt.grid()
    plt.savefig(f'{graph_path}')
    plt.close()

# %%
input_shape = X_train_documents.shape[1]
dropouts = [0.05, 0.15, 0.25, 0.35, 0.50]
learning_rates = [5e-4, 1e-3, 5e-3, 1e-2]
train_seq = 0
for index, dropout in enumerate(dropouts, start=1):
    for learning_rate in learning_rates:
        train_seq += 1
        print('--'*60)
        
        print(f'train {train_seq} initialized...')
        print(f'hyperparams: dropout: {dropout}, learning rate: {learning_rate}')
        
        begin_trainning(train_seq, input_shape, dropout, learning_rate, X_train_documents, y_train_labels)

        print(f'train {train_seq} finished')
        
        print('--'*60)
# Out:
# ------------------------------------------------------------------------------------------------------------------------
# train 1 initialized...
# hyperparams: dropout: 0.05, learning rate: 0.0005
# fold --> 1
# 125/125 [==============================] - 0s 1ms/step
# 125/125 [==============================] - 0s 1ms/step
# fold --> 2
# 125/125 [==============================] - 0s 1ms/step
# 125/125 [==============================] - 0s 2ms/step
# ----------------------------------------
# mean train losses: 0.38163502141833305
# mean train f1 scores: 0.9529670182591282
# mean train accuracies: 0.91025
# ----------------------------------------
# mean val losses: 0.3300510346889496
# mean val f1 scores: 0.9528477149932673
# mean val accuracies: 0.9099999999999999
# ----------------------------------------
# saving graphs...
# finished saving graphs...
# train 1 finished
# ------------------------------------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------------------------------------
# train 2 initialized...
# hyperparams: dropout: 0.05, learning rate: 0.001
# fold --> 1
# 125/125 [==============================] - 0s 1ms/step
# 125/125 [==============================] - 0s 1ms/step
# fold --> 2
# 125/125 [==============================] - 0s 1ms/step
# 125/125 [==============================] - 0s 1ms/step
# ----------------------------------------
# mean train losses: 0.3093968741595745
# mean train f1 scores: 0.9645161811882215
# mean train accuracies: 0.932875
# ----------------------------------------
# mean val losses: 0.2472461797297001
# mean val f1 scores: 0.9615956010181238
# mean val accuracies: 0.92725
# ----------------------------------------
# saving graphs...
# finished saving graphs...
# train 2 finished
# ------------------------------------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------------------------------------
# train 3 initialized...
# hyperparams: dropout: 0.05, learning rate: 0.005
# fold --> 1
# 125/125 [==============================] - 0s 1ms/step
# 125/125 [==============================] - 0s 1ms/step
# fold --> 2
# 125/125 [==============================] - 0s 1ms/step
# 125/125 [==============================] - 0s 1ms/step
# ----------------------------------------
# mean train losses: 0.17990813963115215
# mean train f1 scores: 0.9892310783801987
# mean train accuracies: 0.9802500000000001
# ----------------------------------------
# mean val losses: 0.1367189008742571
# mean val f1 scores: 0.9777357642389815
# mean val accuracies: 0.95875
# ----------------------------------------
# saving graphs...
# finished saving graphs...
# train 3 finished
# ------------------------------------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------------------------------------
# train 4 initialized...
# hyperparams: dropout: 0.05, learning rate: 0.01
# fold --> 1
# 125/125 [==============================] - 0s 2ms/step
# 125/125 [==============================] - 0s 1ms/step
# fold --> 2
# 125/125 [==============================] - 0s 1ms/step
# 125/125 [==============================] - 0s 1ms/step
# ----------------------------------------
# mean train losses: 0.15507630072534084
# mean train f1 scores: 0.9934435952531813
# mean train accuracies: 0.988
# ----------------------------------------
# mean val losses: 0.13172128051519394
# mean val f1 scores: 0.9763682189310358
# mean val accuracies: 0.9565
# ----------------------------------------
# saving graphs...
# finished saving graphs...
# train 4 finished
# ------------------------------------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------------------------------------
# train 5 initialized...
# hyperparams: dropout: 0.15, learning rate: 0.0005
# fold --> 1
# 125/125 [==============================] - 0s 1ms/step
# 125/125 [==============================] - 0s 1ms/step
# fold --> 2
# 125/125 [==============================] - 0s 1ms/step
# 125/125 [==============================] - 0s 1ms/step
# ----------------------------------------
# mean train losses: 0.3693125993013382
# mean train f1 scores: 0.9536553847171134
# mean train accuracies: 0.9116249999999999
# ----------------------------------------
# mean val losses: 0.3166368678212166
# mean val f1 scores: 0.9534726193922212
# mean val accuracies: 0.91125
# ----------------------------------------
# saving graphs...
# finished saving graphs...
# train 5 finished
# ------------------------------------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------------------------------------
# train 6 initialized...
# hyperparams: dropout: 0.15, learning rate: 0.001
# fold --> 1
# 125/125 [==============================] - 0s 1ms/step
# 125/125 [==============================] - 0s 1ms/step
# fold --> 2
# 125/125 [==============================] - 0s 1ms/step
# 125/125 [==============================] - 0s 1ms/step
# ----------------------------------------
# mean train losses: 0.3149464726448059
# mean train f1 scores: 0.9628220132913007
# mean train accuracies: 0.9296249999999999
# ----------------------------------------
# mean val losses: 0.2548317350447178
# mean val f1 scores: 0.9606454400727928
# mean val accuracies: 0.9253750000000001
# ----------------------------------------
# saving graphs...
# finished saving graphs...
# train 6 finished
# ------------------------------------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------------------------------------
# train 7 initialized...
# hyperparams: dropout: 0.15, learning rate: 0.005
# fold --> 1
# 125/125 [==============================] - 0s 1ms/step
# 125/125 [==============================] - 0s 1ms/step
# fold --> 2
# 125/125 [==============================] - 0s 1ms/step
# 125/125 [==============================] - 0s 1ms/step
# ----------------------------------------
# mean train losses: 0.18071430549025536
# mean train f1 scores: 0.9893650813007745
# mean train accuracies: 0.9804999999999999
# ----------------------------------------
# mean val losses: 0.13893264345824718
# mean val f1 scores: 0.9772469299956876
# mean val accuracies: 0.957875
# ----------------------------------------
# saving graphs...
# finished saving graphs...
# train 7 finished
# ------------------------------------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------------------------------------
# train 8 initialized...
# hyperparams: dropout: 0.15, learning rate: 0.01
# fold --> 1
# 125/125 [==============================] - 0s 1ms/step
# 125/125 [==============================] - 0s 1ms/step
# fold --> 2
# 125/125 [==============================] - 0s 1ms/step
# 125/125 [==============================] - 0s 1ms/step
# ----------------------------------------
# mean train losses: 0.17375792190432549
# mean train f1 scores: 0.990019795306927
# mean train accuracies: 0.9817499999999999
# ----------------------------------------
# mean val losses: 0.14384573139250278
# mean val f1 scores: 0.9734051628733965
# mean val accuracies: 0.95075
# ----------------------------------------
# saving graphs...
# finished saving graphs...
# train 8 finished
# ------------------------------------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------------------------------------
# train 9 initialized...
# hyperparams: dropout: 0.25, learning rate: 0.0005
# fold --> 1
# 125/125 [==============================] - 0s 1ms/step
# 125/125 [==============================] - 0s 1ms/step
# fold --> 2
# 125/125 [==============================] - 0s 1ms/step
# 125/125 [==============================] - 0s 1ms/step
# ----------------------------------------
# mean train losses: 0.3953496143221855
# mean train f1 scores: 0.9528478443810586
# mean train accuracies: 0.9099999999999999
# ----------------------------------------
# mean val losses: 0.34148095548152924
# mean val f1 scores: 0.9527853148218995
# mean val accuracies: 0.909875
# ----------------------------------------
# saving graphs...
# finished saving graphs...
# train 9 finished
# ------------------------------------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------------------------------------
# train 10 initialized...
# hyperparams: dropout: 0.25, learning rate: 0.001
# fold --> 1
# 125/125 [==============================] - 0s 1ms/step
# 125/125 [==============================] - 0s 1ms/step
# fold --> 2
# 125/125 [==============================] - 0s 1ms/step
# 125/125 [==============================] - 0s 1ms/step
# ----------------------------------------
# mean train losses: 0.2992572709918022
# mean train f1 scores: 0.9619156579044965
# mean train accuracies: 0.927875
# ----------------------------------------
# mean val losses: 0.23892298340797424
# mean val f1 scores: 0.9605763929347111
# mean val accuracies: 0.92525
# ----------------------------------------
# saving graphs...
# finished saving graphs...
# train 10 finished
# ------------------------------------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------------------------------------
# train 11 initialized...
# hyperparams: dropout: 0.25, learning rate: 0.005
# fold --> 1
# 125/125 [==============================] - 0s 2ms/step
# 125/125 [==============================] - 0s 2ms/step
# fold --> 2
# 125/125 [==============================] - 0s 1ms/step
# 125/125 [==============================] - 0s 1ms/step
# ----------------------------------------
# mean train losses: 0.19177757762372494
# mean train f1 scores: 0.9836330957149331
# mean train accuracies: 0.96975
# ----------------------------------------
# mean val losses: 0.15252534113824368
# mean val f1 scores: 0.9723894232185659
# mean val accuracies: 0.9485
# ----------------------------------------
# saving graphs...
# finished saving graphs...
# train 11 finished
# ------------------------------------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------------------------------------
# train 12 initialized...
# hyperparams: dropout: 0.25, learning rate: 0.01
# fold --> 1
# 125/125 [==============================] - 0s 1ms/step
# 125/125 [==============================] - 0s 1ms/step
# fold --> 2
# 125/125 [==============================] - 0s 1ms/step
# 125/125 [==============================] - 0s 1ms/step
# ----------------------------------------
# mean train losses: 0.1768136192113161
# mean train f1 scores: 0.9895975206069916
# mean train accuracies: 0.9810000000000001
# ----------------------------------------
# mean val losses: 0.14477531798183918
# mean val f1 scores: 0.9726573218069297
# mean val accuracies: 0.949875
# ----------------------------------------
# saving graphs...
# finished saving graphs...
# train 12 finished
# ------------------------------------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------------------------------------
# train 13 initialized...
# hyperparams: dropout: 0.35, learning rate: 0.0005
# fold --> 1
# 125/125 [==============================] - 0s 1ms/step
# 125/125 [==============================] - 0s 1ms/step
# fold --> 2
# 125/125 [==============================] - 0s 1ms/step
# 125/125 [==============================] - 0s 1ms/step
# ----------------------------------------
# mean train losses: 0.39282120764255524
# mean train f1 scores: 0.952598212601582
# mean train accuracies: 0.9095
# ----------------------------------------
# mean val losses: 0.33909058570861816
# mean val f1 scores: 0.9527853148218995
# mean val accuracies: 0.909875
# ----------------------------------------
# saving graphs...
# finished saving graphs...
# train 13 finished
# ------------------------------------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------------------------------------
# train 14 initialized...
# hyperparams: dropout: 0.35, learning rate: 0.001
# fold --> 1
# 125/125 [==============================] - 0s 1ms/step
# 125/125 [==============================] - 0s 1ms/step
# fold --> 2
# 125/125 [==============================] - 0s 1ms/step
# 125/125 [==============================] - 0s 1ms/step
# ----------------------------------------
# mean train losses: 0.32463817670941353
# mean train f1 scores: 0.9600381455667383
# mean train accuracies: 0.92425
# ----------------------------------------
# mean val losses: 0.25960998982191086
# mean val f1 scores: 0.9590385228847302
# mean val accuracies: 0.92225
# ----------------------------------------
# saving graphs...
# finished saving graphs...
# train 14 finished
# ------------------------------------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------------------------------------
# train 15 initialized...
# hyperparams: dropout: 0.35, learning rate: 0.005
# fold --> 1
# 125/125 [==============================] - 0s 1ms/step
# 125/125 [==============================] - 0s 1ms/step
# fold --> 2
# 125/125 [==============================] - 0s 1ms/step
# 125/125 [==============================] - 0s 1ms/step
# ----------------------------------------
# mean train losses: 0.20080886222422123
# mean train f1 scores: 0.9849994941049781
# mean train accuracies: 0.972375
# ----------------------------------------
# mean val losses: 0.15246598795056343
# mean val f1 scores: 0.9746373984666056
# mean val accuracies: 0.952875
# ----------------------------------------
# saving graphs...
# finished saving graphs...
# train 15 finished
# ------------------------------------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------------------------------------
# train 16 initialized...
# hyperparams: dropout: 0.35, learning rate: 0.01
# fold --> 1
# 125/125 [==============================] - 0s 1ms/step
# 125/125 [==============================] - 0s 1ms/step
# fold --> 2
# 125/125 [==============================] - 0s 1ms/step
# 125/125 [==============================] - 0s 1ms/step
# ----------------------------------------
# mean train losses: 0.18321914225816727
# mean train f1 scores: 0.9877386900087723
# mean train accuracies: 0.9775
# ----------------------------------------
# mean val losses: 0.1446274295449257
# mean val f1 scores: 0.975475797042874
# mean val accuracies: 0.9546250000000001
# ----------------------------------------
# saving graphs...
# finished saving graphs...
# train 16 finished
# ------------------------------------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------------------------------------
# train 17 initialized...
# hyperparams: dropout: 0.5, learning rate: 0.0005
# fold --> 1
# 125/125 [==============================] - 0s 1ms/step
# 125/125 [==============================] - 0s 1ms/step
# fold --> 2
# 125/125 [==============================] - 0s 1ms/step
# 125/125 [==============================] - 0s 1ms/step
# ----------------------------------------
# mean train losses: 0.438901387155056
# mean train f1 scores: 0.952598212601582
# mean train accuracies: 0.9095
# ----------------------------------------
# mean val losses: 0.3816917911171913
# mean val f1 scores: 0.952598212601582
# mean val accuracies: 0.9095
# ----------------------------------------
# saving graphs...
# finished saving graphs...
# train 17 finished
# ------------------------------------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------------------------------------
# train 18 initialized...
# hyperparams: dropout: 0.5, learning rate: 0.001
# fold --> 1
# 125/125 [==============================] - 0s 1ms/step
# 125/125 [==============================] - 0s 1ms/step
# fold --> 2
# 125/125 [==============================] - 0s 1ms/step
# 125/125 [==============================] - 0s 1ms/step
# ----------------------------------------
# mean train losses: 0.33735691756010056
# mean train f1 scores: 0.9574314338946548
# mean train accuracies: 0.919125
# ----------------------------------------
# mean val losses: 0.2667349651455879
# mean val f1 scores: 0.9571297262227383
# mean val accuracies: 0.9185
# ----------------------------------------
# saving graphs...
# finished saving graphs...
# train 18 finished
# ------------------------------------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------------------------------------
# train 19 initialized...
# hyperparams: dropout: 0.5, learning rate: 0.005
# fold --> 1
# 125/125 [==============================] - 0s 1ms/step
# 125/125 [==============================] - 0s 1ms/step
# fold --> 2
# 125/125 [==============================] - 0s 1ms/step
# 125/125 [==============================] - 0s 1ms/step
# ----------------------------------------
# mean train losses: 0.2184440642595291
# mean train f1 scores: 0.9827297533016914
# mean train accuracies: 0.968125
# ----------------------------------------
# mean val losses: 0.15607100911438465
# mean val f1 scores: 0.9734038676642751
# mean val accuracies: 0.9505
# ----------------------------------------
# saving graphs...
# finished saving graphs...
# train 19 finished
# ------------------------------------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------------------------------------
# train 20 initialized...
# hyperparams: dropout: 0.5, learning rate: 0.01
# fold --> 1
# 125/125 [==============================] - 0s 1ms/step
# 125/125 [==============================] - 0s 1ms/step
# fold --> 2
# 125/125 [==============================] - 0s 2ms/step
# 125/125 [==============================] - 0s 1ms/step
# ----------------------------------------
# mean train losses: 0.2035287581384182
# mean train f1 scores: 0.9846672794566258
# mean train accuracies: 0.97175
# ----------------------------------------
# mean val losses: 0.14648926258087158
# mean val f1 scores: 0.9748427936735188
# mean val accuracies: 0.9533750000000001
# ----------------------------------------
# saving graphs...
# finished saving graphs...
# train 20 finished
# ------------------------------------------------------------------------------------------------------------------------
