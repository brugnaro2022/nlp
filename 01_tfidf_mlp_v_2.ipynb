# %% [markdown]
# <b>INSTITUTO FEDERAL DE GOIÁS<br/>
# PÓS-GRADUAÇÃO EM INTELIGÊNCIA ARTIFICIAL APLICADA<br/></b>
# Disciplina: Processamento de Linguagem Natural  <br/>
# Professor: Daniel Xavier de Sousa <br/>
# Alunos: Wagner Silva, Cleibson, Marcos Rodrigues
#
#
# ---

# %%
import pandas as pd
import numpy as np

from tqdm import tqdm

import nltk
nltk.download('stopwords')
nltk.download('punkt')
from nltk.stem import SnowballStemmer
from nltk.corpus import stopwords

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split, KFold

'''
confusion_matrix, 
roc_curve, 
auc, 
accuracy_score, 
log_loss, 
f1_score, 
recall_score, 
precision_score, 
classification_report, 
average_precision_score, 
precision_recall_curve, 
roc_curve, 
auc
'''

from sklearn.metrics import f1_score, accuracy_score, confusion_matrix, roc_curve, auc

import tensorflow as tf
from tensorflow import keras
from keras.models import Sequential
from tensorflow.keras.layers import Embedding, Dense, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping

import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation
import seaborn as sbn
# Out:
# [nltk_data] Downloading package stopwords to /home/marcos/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /home/marcos/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# 2023-09-03 23:39:12.488396: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-09-03 23:39:13.009788: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-09-03 23:39:14.393076: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
df = pd.read_csv(f'../datasets/buscape_preprocessed.csv')

# %%
df.shape
# Out:
# (133438, 2)

# %%
df.head(3)
# Out:
#                                          review_text  rating
# 0  estou muito satisfeito o visor e melhor do que...       1
# 1  muito boa o que gostei preco o que nao gostei ...       1
# 2  rapida otima qualidade de impressao e facil de...       1

# %%
df = df[:30000]

# %%
df['rating'].value_counts()
# Out:
# rating
# 1    27265
# 0     2735
# Name: count, dtype: int64

# %%
documents = df['review_text'].tolist()
labels = df['rating']

# %%
# Steamming
stemmer = SnowballStemmer("portuguese")

def custom_tokenizer(text):
    tokens = nltk.word_tokenize(text)
    stemmed_tokens = [stemmer.stem(token) for token in tokens]
    return stemmed_tokens

tfidf_vectorizer = TfidfVectorizer(
    # Steamming
    tokenizer=custom_tokenizer,
    # Removing stopwords
    stop_words=stopwords.words('portuguese'),
    ngram_range=(1,2),
    min_df=8,
    max_df=0.3,
    max_features=5000
)
#tfidf_vectorizer.get_feature_names_out()

# %%
tfidf_matrix = tfidf_vectorizer.fit_transform(documents)
# Out:
# /home/marcos/anaconda3/envs/test_env/lib/python3.10/site-packages/sklearn/feature_extraction/text.py:525: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   warnings.warn(
# /home/marcos/anaconda3/envs/test_env/lib/python3.10/site-packages/sklearn/feature_extraction/text.py:408: UserWarning: Your stop_words may be inconsistent with your preprocessing. Tokenizing the stop words generated tokens ['aquel', 'aquil', 'del', 'depo', 'estam', 'estav', 'estej', 'estev', 'estiv', 'estivéss', 'estáv', 'estã', 'fom', 'form', 'foss', 'fôr', 'fôss', 'haj', 'hav', 'houv', 'houvéss', 'hã', 'mesm', 'minh', 'muit', 'noss', 'nã', 'par', 'pel', 'quand', 'sej', 'serã', 'som', 'sã', 'tenh', 'ter', 'terã', 'tev', 'tinh', 'tiv', 'tivéss', 'tính', 'voc', 'éram'] not in stop_words.
#   warnings.warn(

# %%
label_encoder = LabelEncoder()
encoded_labels = label_encoder.fit_transform(labels)

# %%
X_train_documents, X_test_documents, y_train_labels, y_test_labels = train_test_split(tfidf_matrix, encoded_labels, test_size=0.2, random_state=42)

# %%
def begin_trainning(train_seq, input_shape, dropout, learning_rate, X_train_documents, y_train_labels):
    
    model = Sequential()
    model.add(Dense(24, activation='relu', input_shape=(input_shape,)))
    model.add(Dropout(dropout)),
    model.add(Dense(1, activation='sigmoid'))

    model.compile(optimizer=Adam(learning_rate=learning_rate), loss='binary_crossentropy', metrics=['acc'])
    
    k_folds = 10
    kfolds=KFold(n_splits=k_folds, shuffle=True, random_state=42)
    
    train_losses = []
    train_f1_scores = []
    train_accuracies = []
    train_history_accuracies = []
    
    val_losses = []
    val_f1_scores = []
    val_accuracies = []

    val_tprs = []
    val_aucs = []
    val_mean_fpr = np.linspace(0, 1, 100)

    for fold, (train_idx, test_idx) in enumerate(kfolds.split(X_train_documents), start=1):
        print(f'fold --> {fold}')

        X_train, X_test = X_train_documents[train_idx], X_train_documents[test_idx]
        y_train, y_test = y_train_labels[train_idx], y_train_labels[test_idx]

        model_history = model.fit(
            X_train.toarray(),
            y_train,
            epochs=5,
            batch_size=32,
            callbacks=[EarlyStopping('loss', patience=3)],
            validation_data=(X_test.toarray(), y_test),
            verbose=0
        )
        
        train_loss = model_history.history['loss']
        train_losses.append(train_loss)
        
        train_history_accuracie = model_history.history['acc']
        train_history_accuracies.append(train_history_accuracie)
        
        train_pred = (model.predict(X_train.toarray()) > 0.5).astype(int)
        
        train_f1_sc = f1_score(y_train, train_pred)
        train_f1_scores.append(train_f1_sc)
        
        train_acc= accuracy_score(y_train, train_pred)
        train_accuracies.append(train_acc)
        
        # -----------------------------------------------------------------------------------
        
        val_loss = model_history.history['val_loss']
        val_losses.append(val_loss)
    
        val_pred = (model.predict(X_test.toarray()) > 0.5).astype(int)
        
        val_f1_sc = f1_score(y_test, val_pred)
        val_f1_scores.append(val_f1_sc)
        
        val_accuracy = accuracy_score(y_test, val_pred)
        val_accuracies.append(val_accuracy)
        
        fpr, tpr, thresholds = roc_curve(y_test, val_pred)
        val_roc_auc = auc(fpr, tpr)
        val_tprs.append(np.interp(val_mean_fpr, fpr, tpr))
        val_aucs.append(val_roc_auc)
        
    print('--'*20)
    print(f'mean train losses: {np.mean(train_losses)}')
    print(f'mean train f1 scores: {np.mean(train_f1_scores)}')
    print(f'mean train accuracies: {np.mean(train_accuracies)}')
    print('--'*20)
    print(f'mean val losses: {np.mean(val_losses)}')
    print(f'mean val f1 scores: {np.mean(val_f1_scores)}')
    print(f'mean val accuracies: {np.mean(val_accuracies)}')
    print('--'*20)
    
    print('saving graphs...')
    
    plot_eval_train_test_graph(model_history, 'loss', train_seq)
    plot_eval_train_test_graph(model_history, 'acc', train_seq)
    plot_train_folds(train_losses, 'loss')
    plot_train_folds(train_history_accuracies, 'acc')
    
    predict = np.round(model.predict(X_test.toarray()))
    accuracy = accuracy_score(y_test, predict)
    val_conf_matrix = confusion_matrix(y_test, predict)
    plot_confunsion_matrix(val_conf_matrix, 'val')
    
    val_mean_tpr = np.mean(val_tprs, axis=0)
    val_mean_auc = auc(val_mean_fpr, val_mean_tpr)
    plot_roc_auc_curve('val', val_mean_tpr, val_mean_auc, val_mean_fpr, train_seq)
    
    print('finished saving graphs...')

# %%
def plot_eval_train_test_graph(history, metric, train_seq):
    
    train_arr = history.history[f'{metric}']
    val_arr = history.history[f'val_{metric}']
    
    epochs = range(1, len(train_arr) + 1)
    
    graph_path = f'./graphs/01_tfidf_mlp_v_2/train_test_{metric}/train_seq_{train_seq}.png'
    
    plt.figure(figsize=(10, 6))
    plt.plot(epochs, train_arr, 'b', label=f'Training {metric}')
    plt.plot(epochs, val_arr, 'r', label='Test Loss')

    plt.title(f'Train and Test {metric}')
    plt.xlabel('Epochs')
    plt.ylabel(f'{metric}')
    plt.legend()

    plt.grid()
    plt.savefig(f'{graph_path}')
    #plt.show()
    plt.close()
    
def plot_train_folds(history, metric):
    graph_path = f'./graphs/01_tfidf_mlp_v_2/folds_train_{metric}/train_seq_{train_seq}.png'
    
    plt.figure(figsize=(10, 6))
    for fold_num, fold_loss in enumerate(history):
        plt.plot(fold_loss, label=f'Fold {fold_num+1}')
    plt.xlabel('Epoch')
    plt.ylabel(f'Training {metric}')
    plt.title(f'Training {metric} per Epoch for Each Fold')
    plt.legend()
    plt.savefig(f'{graph_path}')
    #plt.show()
    plt.close()
    
def plot_confunsion_matrix(cm, metric):
    graph_path = f'./graphs/01_tfidf_mlp_v_2/confusion_matrix_{metric}/train_seq_{train_seq}.png'
    plt.figure(figsize=(6,4))
    sbn.heatmap(cm, annot=True, linewidth=0.2, annot_kws={'size':12}, fmt='.0f')
    plt.title(f"Confusion Matrix - {metric}", fontsize=12)
    plt.xlabel('Real')
    plt.ylabel('Predict')
    plt.savefig(f'{graph_path}')
    #plt.show()
    plt.close()
    
def plot_roc_auc_curve(desc, mean_tpr, mean_auc, mean_fpr, train_seq):
    graph_path = f'./graphs/01_tfidf_mlp_v_2/roc_curve_{desc}/train_seq_{train_seq}.png'
    plt.figure()
    plt.plot(mean_fpr, mean_tpr, color='b', label=f'{desc} Mean ROC curve (AUC = {mean_auc:.2f})')
    plt.plot([0, 1], [0, 1], color='gray', linestyle='--')
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title(f'{desc} Mean Receiver Operating Characteristic (ROC) Curve')
    plt.legend(loc="lower right")
    plt.savefig(graph_path)
    #plt.show()
    plt.close()

# %%
input_shape = X_train_documents.shape[1]
dropouts = [0.05, 0.15, 0.25, 0.35, 0.50]
learning_rates = [5e-4, 1e-3, 5e-3, 1e-2]
train_seq = 0
for index, dropout in enumerate(dropouts, start=1):
    for learning_rate in learning_rates:
        train_seq += 1
        print('--'*40)
        
        print(f'train {train_seq} initialized...')
        print(f'hyperparams: dropout: {dropout}, learning rate: {learning_rate}')
        
        begin_trainning(train_seq, input_shape, dropout, learning_rate, X_train_documents, y_train_labels)

        print(f'train {train_seq} finished')
        
        print('--'*40)
# Out:
# --------------------------------------------------------------------------------
# train 1 initialized...
# hyperparams: dropout: 0.05, learning rate: 0.0005
# fold --> 1
# 675/675 [==============================] - 1s 1ms/step
# 75/75 [==============================] - 0s 1ms/step
# fold --> 2
# 675/675 [==============================] - 1s 1ms/step
# 75/75 [==============================] - 0s 1ms/step
# fold --> 3
# 675/675 [==============================] - 1s 1ms/step
# 75/75 [==============================] - 0s 1ms/step
# fold --> 4
# 675/675 [==============================] - 1s 1ms/step
# 75/75 [==============================] - 0s 1ms/step
# fold --> 5
# 675/675 [==============================] - 1s 1ms/step
# 75/75 [==============================] - 0s 1ms/step
# fold --> 6
# 675/675 [==============================] - 1s 1ms/step
# 75/75 [==============================] - 0s 1ms/step
# fold --> 7
# 675/675 [==============================] - 1s 1ms/step
# 75/75 [==============================] - 0s 1ms/step
# fold --> 8
# 675/675 [==============================] - 1s 1ms/step
# 75/75 [==============================] - 0s 1ms/step
# fold --> 9
# 675/675 [==============================] - 1s 1ms/step
# 75/75 [==============================] - 0s 1ms/step
# fold --> 10
# 675/675 [==============================] - 1s 1ms/step
# 75/75 [==============================] - 0s 1ms/step
# ----------------------------------------
# mean train losses: 0.045356000140309334
# mean train f1 scores: 0.9955028526410123
# mean train accuracies: 0.9917685185185185
# ----------------------------------------
# mean val losses: 0.05331870795227587
# mean val f1 scores: 0.9896170473374554
# mean val accuracies: 0.9809999999999999
# ----------------------------------------
# saving graphs...
# 75/75 [==============================] - 0s 5ms/step
# finished saving graphs...
# train 1 finished
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# train 2 initialized...
# hyperparams: dropout: 0.05, learning rate: 0.001
# fold --> 1
# 675/675 [==============================] - 1s 1ms/step
# 75/75 [==============================] - 0s 1ms/step
# fold --> 2
# 675/675 [==============================] - 1s 1ms/step
# 75/75 [==============================] - 0s 1ms/step
# fold --> 3
# 675/675 [==============================] - 1s 1ms/step
# 75/75 [==============================] - 0s 1ms/step
# fold --> 4
# 675/675 [==============================] - 1s 1ms/step
# 75/75 [==============================] - 0s 1ms/step
# fold --> 5
# 675/675 [==============================] - 1s 1ms/step
# 75/75 [==============================] - 0s 1ms/step
# fold --> 6
# 675/675 [==============================] - 1s 1ms/step
# 75/75 [==============================] - 0s 1ms/step
# fold --> 7
# 675/675 [==============================] - 1s 1ms/step
# 75/75 [==============================] - 0s 1ms/step
# fold --> 8
# 675/675 [==============================] - 1s 1ms/step
# 75/75 [==============================] - 0s 1ms/step
# fold --> 9
# 675/675 [==============================] - 1s 1ms/step
# 75/75 [==============================] - 0s 1ms/step
# fold --> 10
# 675/675 [==============================] - 1s 1ms/step
# 75/75 [==============================] - 0s 1ms/step
# ----------------------------------------
# mean train losses: 0.030189385004341603
# mean train f1 scores: 0.9975380983633716
# mean train accuracies: 0.9955046296296295
# ----------------------------------------
# mean val losses: 0.04020088150165975
# mean val f1 scores: 0.9914017430549181
# mean val accuracies: 0.9842916666666668
# ----------------------------------------
# saving graphs...
# 75/75 [==============================] - 0s 1ms/step
# finished saving graphs...
# train 2 finished
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# train 3 initialized...
# hyperparams: dropout: 0.05, learning rate: 0.005
# fold --> 1
# 675/675 [==============================] - 1s 1ms/step
# 75/75 [==============================] - 0s 1ms/step
# fold --> 2
# 675/675 [==============================] - 1s 1ms/step
# 75/75 [==============================] - 0s 1ms/step
# fold --> 3
# 675/675 [==============================] - 1s 1ms/step
# 75/75 [==============================] - 0s 1ms/step
# fold --> 4
# 675/675 [==============================] - 1s 1ms/step
# 75/75 [==============================] - 0s 1ms/step
# fold --> 5
# 675/675 [==============================] - 1s 1ms/step
# 75/75 [==============================] - 0s 1ms/step
# fold --> 6
# 675/675 [==============================] - 1s 1ms/step
# 75/75 [==============================] - 0s 1ms/step
# fold --> 7
# 675/675 [==============================] - 1s 1ms/step
# 75/75 [==============================] - 0s 1ms/step
# fold --> 8
# 675/675 [==============================] - 1s 1ms/step
# 75/75 [==============================] - 0s 1ms/step
# fold --> 9
# 675/675 [==============================] - 1s 1ms/step
# 75/75 [==============================] - 0s 1ms/step
# fold --> 10
# 675/675 [==============================] - 1s 1ms/step
# 75/75 [==============================] - 0s 1ms/step
# ----------------------------------------
# mean train losses: 0.018981346748769282
# mean train f1 scores: 0.999082493499469
# mean train accuracies: 0.9983287037037035
# ----------------------------------------
# mean val losses: 0.03439890497131273
# mean val f1 scores: 0.9940342611072742
# mean val accuracies: 0.9890833333333333
# ----------------------------------------
# saving graphs...
# 75/75 [==============================] - 0s 1ms/step
# finished saving graphs...
# train 3 finished
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# train 4 initialized...
# hyperparams: dropout: 0.05, learning rate: 0.01
# fold --> 1
# 675/675 [==============================] - 1s 1ms/step
# 75/75 [==============================] - 0s 1ms/step
# fold --> 2
# 675/675 [==============================] - 1s 1ms/step
# 75/75 [==============================] - 0s 1ms/step
# fold --> 3
# 675/675 [==============================] - 1s 1ms/step
# 75/75 [==============================] - 0s 1ms/step
# fold --> 4
# 675/675 [==============================] - 1s 1ms/step
# 75/75 [==============================] - 0s 1ms/step
# fold --> 5
# 675/675 [==============================] - 1s 1ms/step
# 75/75 [==============================] - 0s 1ms/step
# fold --> 6
# 675/675 [==============================] - 1s 1ms/step
# 75/75 [==============================] - 0s 1ms/step
# fold --> 7
# 675/675 [==============================] - 1s 1ms/step
# 75/75 [==============================] - 0s 1ms/step
# fold --> 8
# 675/675 [==============================] - 1s 1ms/step
# 75/75 [==============================] - 0s 1ms/step
# fold --> 9
# 675/675 [==============================] - 1s 1ms/step
# 75/75 [==============================] - 0s 1ms/step
# fold --> 10
# 675/675 [==============================] - 1s 1ms/step
# 75/75 [==============================] - 0s 1ms/step
# ----------------------------------------
# mean train losses: 0.021012089559808374
# mean train f1 scores: 0.9991045056906944
# mean train accuracies: 0.9983703703703704
# ----------------------------------------
# mean val losses: 0.03776782277040183
# mean val f1 scores: 0.9936043537582699
# mean val accuracies: 0.9883333333333333
# ----------------------------------------
# saving graphs...
# 75/75 [==============================] - 0s 1ms/step
# finished saving graphs...
# train 4 finished
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# train 5 initialized...
# hyperparams: dropout: 0.15, learning rate: 0.0005
# fold --> 1
# 675/675 [==============================] - 1s 1ms/step
# 75/75 [==============================] - 0s 1ms/step
# fold --> 2
# 675/675 [==============================] - 1s 1ms/step
# 75/75 [==============================] - 0s 1ms/step
# fold --> 3
# 675/675 [==============================] - 1s 1ms/step
# 75/75 [==============================] - 0s 1ms/step
# fold --> 4
# 675/675 [==============================] - 1s 1ms/step
# 75/75 [==============================] - 0s 1ms/step
# fold --> 5
# 675/675 [==============================] - 1s 1ms/step
# 75/75 [==============================] - 0s 1ms/step
# fold --> 6
# 675/675 [==============================] - 1s 1ms/step
# 75/75 [==============================] - 0s 1ms/step
# fold --> 7
# 675/675 [==============================] - 1s 1ms/step
# 75/75 [==============================] - 0s 1ms/step
# fold --> 8
# 675/675 [==============================] - 1s 1ms/step
# 75/75 [==============================] - 0s 1ms/step
# fold --> 9
# 675/675 [==============================] - 1s 1ms/step
# 75/75 [==============================] - 0s 1ms/step
# fold --> 10
# 675/675 [==============================] - 1s 1ms/step
# 75/75 [==============================] - 0s 1ms/step
# ----------------------------------------
# mean train losses: 0.05060383319854736
# mean train f1 scores: 0.994684117718557
# mean train accuracies: 0.9902731481481482
# ----------------------------------------
# mean val losses: 0.055314379688352344
# mean val f1 scores: 0.9896337584069798
# mean val accuracies: 0.9810416666666667
# ----------------------------------------
# saving graphs...
# 75/75 [==============================] - 0s 1ms/step
# finished saving graphs...
# train 5 finished
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# train 6 initialized...
# hyperparams: dropout: 0.15, learning rate: 0.001
# fold --> 1
# 675/675 [==============================] - 1s 1ms/step
# 75/75 [==============================] - 0s 1ms/step
# fold --> 2
# 675/675 [==============================] - 1s 1ms/step
# 75/75 [==============================] - 0s 1ms/step
# fold --> 3
# 675/675 [==============================] - 1s 1ms/step
# 75/75 [==============================] - 0s 1ms/step
# fold --> 4
# 675/675 [==============================] - 1s 1ms/step
# 75/75 [==============================] - 0s 1ms/step
# fold --> 5
# 675/675 [==============================] - 1s 1ms/step
# 75/75 [==============================] - 0s 1ms/step
# fold --> 6
# 675/675 [==============================] - 1s 1ms/step
# 75/75 [==============================] - 0s 1ms/step
# fold --> 7
# 675/675 [==============================] - 1s 1ms/step
# 75/75 [==============================] - 0s 1ms/step
# fold --> 8
# 675/675 [==============================] - 1s 1ms/step
# 75/75 [==============================] - 0s 2ms/step
# fold --> 9
# 675/675 [==============================] - 1s 1ms/step
# 75/75 [==============================] - 0s 1ms/step
# fold --> 10
# 675/675 [==============================] - 1s 1ms/step
# 75/75 [==============================] - 0s 1ms/step
# ----------------------------------------
# mean train losses: 0.03420804664492607
# mean train f1 scores: 0.9970201549287172
# mean train accuracies: 0.9945555555555556
# ----------------------------------------
# mean val losses: 0.039858842454850676
# mean val f1 scores: 0.9920972227431873
# mean val accuracies: 0.9855416666666666
# ----------------------------------------
# saving graphs...
# 75/75 [==============================] - 0s 1ms/step
# finished saving graphs...
# train 6 finished
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# train 7 initialized...
# hyperparams: dropout: 0.15, learning rate: 0.005
# fold --> 1
# 675/675 [==============================] - 1s 1ms/step
# 75/75 [==============================] - 0s 1ms/step
# fold --> 2
# 675/675 [==============================] - 1s 1ms/step
# 75/75 [==============================] - 0s 1ms/step
# fold --> 3
# 675/675 [==============================] - 1s 1ms/step
# 75/75 [==============================] - 0s 1ms/step
# fold --> 4
# 675/675 [==============================] - 1s 1ms/step
# 75/75 [==============================] - 0s 1ms/step
# fold --> 5
# 675/675 [==============================] - 1s 1ms/step
# 75/75 [==============================] - 0s 1ms/step
# fold --> 6
# 675/675 [==============================] - 1s 1ms/step
# 75/75 [==============================] - 0s 1ms/step
# fold --> 7
# 675/675 [==============================] - 1s 1ms/step
# 75/75 [==============================] - 0s 1ms/step
# fold --> 8
# 675/675 [==============================] - 1s 1ms/step
# 75/75 [==============================] - 0s 1ms/step
# fold --> 9
# 675/675 [==============================] - 1s 1ms/step
# 75/75 [==============================] - 0s 1ms/step
# fold --> 10
# 675/675 [==============================] - 1s 1ms/step
# 75/75 [==============================] - 0s 1ms/step
# ----------------------------------------
# mean train losses: 0.02196927636861801
# mean train f1 scores: 0.9986300823131564
# mean train accuracies: 0.9974999999999999
# ----------------------------------------
# mean val losses: 0.0358622016152367
# mean val f1 scores: 0.9936841535883201
# mean val accuracies: 0.9884583333333333
# ----------------------------------------
# saving graphs...
# 75/75 [==============================] - 0s 1ms/step
# finished saving graphs...
# train 7 finished
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# train 8 initialized...
# hyperparams: dropout: 0.15, learning rate: 0.01
# fold --> 1
# 675/675 [==============================] - 1s 1ms/step
# 75/75 [==============================] - 0s 1ms/step
# fold --> 2
# 675/675 [==============================] - 1s 1ms/step
# 75/75 [==============================] - 0s 1ms/step
# fold --> 3
# 675/675 [==============================] - 1s 1ms/step
# 75/75 [==============================] - 0s 1ms/step
# fold --> 4
# 675/675 [==============================] - 1s 1ms/step
# 75/75 [==============================] - 0s 1ms/step
# fold --> 5
# 675/675 [==============================] - 1s 1ms/step
# 75/75 [==============================] - 0s 1ms/step
# fold --> 6
# 675/675 [==============================] - 1s 1ms/step
# 75/75 [==============================] - 0s 1ms/step
# fold --> 7
# 675/675 [==============================] - 1s 1ms/step
# 75/75 [==============================] - 0s 1ms/step
# fold --> 8
# 675/675 [==============================] - 1s 1ms/step
# 75/75 [==============================] - 0s 1ms/step
# fold --> 9
# 675/675 [==============================] - 1s 1ms/step
# 75/75 [==============================] - 0s 1ms/step
# fold --> 10
# 675/675 [==============================] - 1s 1ms/step
# 75/75 [==============================] - 0s 1ms/step
# ----------------------------------------
# mean train losses: 0.02514520801603794
# mean train f1 scores: 0.9988844300092685
# mean train accuracies: 0.9979675925925926
# ----------------------------------------
# mean val losses: 0.03611445344053209
# mean val f1 scores: 0.9936046864405412
# mean val accuracies: 0.9883333333333335
# ----------------------------------------
# saving graphs...
# 75/75 [==============================] - 0s 1ms/step
# finished saving graphs...
# train 8 finished
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# train 9 initialized...
# hyperparams: dropout: 0.25, learning rate: 0.0005
# fold --> 1
# 675/675 [==============================] - 1s 1ms/step
# 75/75 [==============================] - 0s 1ms/step
# fold --> 2
# 675/675 [==============================] - 1s 1ms/step
# 75/75 [==============================] - 0s 1ms/step
# fold --> 3
# 675/675 [==============================] - 1s 1ms/step
# 75/75 [==============================] - 0s 1ms/step
# fold --> 4
# 675/675 [==============================] - 1s 1ms/step
# 75/75 [==============================] - 0s 1ms/step
# fold --> 5
# 675/675 [==============================] - 1s 1ms/step
# 75/75 [==============================] - 0s 1ms/step
# fold --> 6
# 675/675 [==============================] - 1s 1ms/step
# 75/75 [==============================] - 0s 1ms/step
# fold --> 7
# 675/675 [==============================] - 1s 1ms/step
# 75/75 [==============================] - 0s 1ms/step
# fold --> 8
# 675/675 [==============================] - 1s 1ms/step
# 75/75 [==============================] - 0s 1ms/step
# fold --> 9
# 675/675 [==============================] - 1s 1ms/step
# 75/75 [==============================] - 0s 1ms/step
# fold --> 10
# 675/675 [==============================] - 1s 1ms/step
# 75/75 [==============================] - 0s 1ms/step
# ----------------------------------------
# mean train losses: 0.05254892831668258
# mean train f1 scores: 0.9943642993144393
# mean train accuracies: 0.9896898148148148
# ----------------------------------------
# mean val losses: 0.05594914799556136
# mean val f1 scores: 0.9894751086398571
# mean val accuracies: 0.9807499999999999
# ----------------------------------------
# saving graphs...
# 75/75 [==============================] - 0s 1ms/step
# finished saving graphs...
# train 9 finished
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# train 10 initialized...
# hyperparams: dropout: 0.25, learning rate: 0.001
# fold --> 1
# 675/675 [==============================] - 1s 1ms/step
# 75/75 [==============================] - 0s 1ms/step
# fold --> 2
# 675/675 [==============================] - 1s 1ms/step
# 75/75 [==============================] - 0s 1ms/step
# fold --> 3
# 675/675 [==============================] - 1s 1ms/step
# 75/75 [==============================] - 0s 1ms/step
# fold --> 4
# 675/675 [==============================] - 1s 1ms/step
# 75/75 [==============================] - 0s 1ms/step
# fold --> 5
# 675/675 [==============================] - 1s 1ms/step
# 75/75 [==============================] - 0s 1ms/step
# fold --> 6
# 675/675 [==============================] - 1s 1ms/step
# 75/75 [==============================] - 0s 1ms/step
# fold --> 7
# 675/675 [==============================] - 1s 1ms/step
# 75/75 [==============================] - 0s 1ms/step
# fold --> 8
# 675/675 [==============================] - 1s 1ms/step
# 75/75 [==============================] - 0s 1ms/step
# fold --> 9
# 675/675 [==============================] - 1s 1ms/step
# 75/75 [==============================] - 0s 1ms/step
# fold --> 10
# 675/675 [==============================] - 1s 1ms/step
# 75/75 [==============================] - 0s 1ms/step
# ----------------------------------------
# mean train losses: 0.036639940831810235
# mean train f1 scores: 0.9967681665384733
# mean train accuracies: 0.9940925925925926
# ----------------------------------------
# mean val losses: 0.043462608121335504
# mean val f1 scores: 0.9912276407886461
# mean val accuracies: 0.9839583333333334
# ----------------------------------------
# saving graphs...
# 75/75 [==============================] - 0s 1ms/step
# finished saving graphs...
# train 10 finished
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# train 11 initialized...
# hyperparams: dropout: 0.25, learning rate: 0.005
# fold --> 1
# 675/675 [==============================] - 1s 1ms/step
# 75/75 [==============================] - 0s 1ms/step
# fold --> 2
# 675/675 [==============================] - 1s 1ms/step
# 75/75 [==============================] - 0s 1ms/step
# fold --> 3
# 675/675 [==============================] - 1s 1ms/step
# 75/75 [==============================] - 0s 1ms/step
# fold --> 4
# 675/675 [==============================] - 1s 1ms/step
# 75/75 [==============================] - 0s 1ms/step
# fold --> 5
# 675/675 [==============================] - 1s 1ms/step
# 75/75 [==============================] - 0s 1ms/step
# fold --> 6
# 675/675 [==============================] - 1s 1ms/step
# 75/75 [==============================] - 0s 1ms/step
# fold --> 7
# 675/675 [==============================] - 1s 1ms/step
# 75/75 [==============================] - 0s 1ms/step
# fold --> 8
# 675/675 [==============================] - 1s 1ms/step
# 75/75 [==============================] - 0s 1ms/step
# fold --> 9
# 675/675 [==============================] - 1s 1ms/step
# 75/75 [==============================] - 0s 1ms/step
# fold --> 10
# 675/675 [==============================] - 1s 1ms/step
# 75/75 [==============================] - 0s 2ms/step
# ----------------------------------------
# mean train losses: 0.028873651176691054
# mean train f1 scores: 0.9983158632072655
# mean train accuracies: 0.996925925925926
# ----------------------------------------
# mean val losses: 0.037929146576207134
# mean val f1 scores: 0.9933505700849292
# mean val accuracies: 0.9878333333333333
# ----------------------------------------
# saving graphs...
# 75/75 [==============================] - 0s 2ms/step
# finished saving graphs...
# train 11 finished
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# train 12 initialized...
# hyperparams: dropout: 0.25, learning rate: 0.01
# fold --> 1
# 675/675 [==============================] - 1s 1ms/step
# 75/75 [==============================] - 0s 1ms/step
# fold --> 2
# 675/675 [==============================] - 1s 1ms/step
# 75/75 [==============================] - 0s 1ms/step
# fold --> 3
# 675/675 [==============================] - 1s 1ms/step
# 75/75 [==============================] - 0s 2ms/step
# fold --> 4
# 675/675 [==============================] - 1s 1ms/step
# 75/75 [==============================] - 0s 1ms/step
# fold --> 5
# 675/675 [==============================] - 1s 1ms/step
# 75/75 [==============================] - 0s 1ms/step
# fold --> 6
# 675/675 [==============================] - 1s 1ms/step
# 75/75 [==============================] - 0s 1ms/step
# fold --> 7
# 675/675 [==============================] - 1s 1ms/step
# 75/75 [==============================] - 0s 1ms/step
# fold --> 8
# 675/675 [==============================] - 1s 1ms/step
# 75/75 [==============================] - 0s 1ms/step
# fold --> 9
# 675/675 [==============================] - 1s 1ms/step
# 75/75 [==============================] - 0s 1ms/step
# fold --> 10
# 675/675 [==============================] - 1s 1ms/step
# 75/75 [==============================] - 0s 1ms/step
# ----------------------------------------
# mean train losses: [0.01889454 0.01178578 0.00889207 0.00706752 0.00552256 0.0072428
#  0.00555229 0.00448417 0.00386839 0.00326737 0.00382359 0.00284598
#  0.00258739 0.00250293 0.00199675 0.00261508 0.00219228 0.00202722
#  0.00177589 0.00193401 0.00190244 0.00165498 0.00169931 0.00153276
#  0.00134433 0.00160842 0.00127227 0.00138078 0.00139364 0.00126749
#  0.00120381 0.00122117 0.00126944 0.00140039 0.00132612 0.00116552
#  0.00113766 0.0010535  0.00102163 0.00113851 0.00119279 0.00087932
#  0.00132826 0.00088231 0.00115534 0.00109764 0.00104031 0.00108298
#  0.00085284]
# mean train f1 scores: 0.9985687637724311
# mean train accuracies: 0.997388888888889
# ----------------------------------------
# mean val losses: [0.01697398 0.01783807 0.02099599 0.02617978 0.02847752 0.00384873
#  0.00470018 0.00503837 0.00571844 0.00735776 0.00212043 0.00266229
#  0.00310096 0.00399349 0.00519831 0.00104088 0.00125705 0.00172341
#  0.00189978 0.00223406 0.00112733 0.00125554 0.0016726  0.00219541
#  0.00210252 0.00070592 0.00070516 0.00086741 0.00092982 0.00088179
#  0.00069979 0.00068585 0.00077792 0.00105614 0.00034626 0.00033207
#  0.0004581  0.00056752 0.00061732 0.0002427  0.00027563 0.00034719
#  0.0003718  0.00042085 0.00059061 0.0006595  0.00090436 0.00101606
#  0.00126661]
# mean val f1 scores: 0.9938655751756145
# mean val accuracies: 0.9887916666666665
# ----------------------------------------
# saving graphs...
# /home/marcos/anaconda3/envs/test_env/lib/python3.10/site-packages/numpy/core/_methods.py:164: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   arr = asanyarray(a)
# 75/75 [==============================] - 0s 1ms/step
# finished saving graphs...
# train 12 finished
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# train 13 initialized...
# hyperparams: dropout: 0.35, learning rate: 0.0005
# fold --> 1
# 675/675 [==============================] - 1s 973us/step
# 75/75 [==============================] - 0s 1ms/step
# fold --> 2
# 675/675 [==============================] - 1s 1ms/step
# 75/75 [==============================] - 0s 1ms/step
# fold --> 3
# 675/675 [==============================] - 1s 971us/step
# 75/75 [==============================] - 0s 1ms/step
# fold --> 4
# 675/675 [==============================] - 1s 990us/step
# 75/75 [==============================] - 0s 1ms/step
# fold --> 5
# 675/675 [==============================] - 1s 984us/step
# 75/75 [==============================] - 0s 1000us/step
# fold --> 6
# 675/675 [==============================] - 1s 979us/step
# 75/75 [==============================] - 0s 1ms/step
# fold --> 7
# 675/675 [==============================] - 1s 970us/step
# 75/75 [==============================] - 0s 1ms/step
# fold --> 8
# 675/675 [==============================] - 1s 961us/step
# 75/75 [==============================] - 0s 1ms/step
# fold --> 9
# 675/675 [==============================] - 1s 981us/step
# 75/75 [==============================] - 0s 1ms/step
# fold --> 10
# 675/675 [==============================] - 1s 987us/step
# 75/75 [==============================] - 0s 1ms/step
# ----------------------------------------
# mean train losses: 0.06364738579839468
# mean train f1 scores: 0.993492867767029
# mean train accuracies: 0.9880787037037037
# ----------------------------------------
# mean val losses: 0.06045606004074216
# mean val f1 scores: 0.9896010467721075
# mean val accuracies: 0.9809583333333334
# ----------------------------------------
# saving graphs...
# 75/75 [==============================] - 0s 1ms/step
# finished saving graphs...
# train 13 finished
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# train 14 initialized...
# hyperparams: dropout: 0.35, learning rate: 0.001
# fold --> 1
# 675/675 [==============================] - 1s 970us/step
# 75/75 [==============================] - 0s 1ms/step
# fold --> 2
# 675/675 [==============================] - 1s 976us/step
# 75/75 [==============================] - 0s 1ms/step
# fold --> 3
# 675/675 [==============================] - 1s 966us/step
# 75/75 [==============================] - 0s 1ms/step
# fold --> 4
# 675/675 [==============================] - 1s 987us/step
# 75/75 [==============================] - 0s 980us/step
# fold --> 5
# 675/675 [==============================] - 1s 980us/step
# 75/75 [==============================] - 0s 1ms/step
# fold --> 6
# 675/675 [==============================] - 1s 1ms/step
# 75/75 [==============================] - 0s 1ms/step
# fold --> 7
# 675/675 [==============================] - 1s 978us/step
# 75/75 [==============================] - 0s 1ms/step
# fold --> 8
# 675/675 [==============================] - 1s 1ms/step
# 75/75 [==============================] - 0s 1ms/step
# fold --> 9
# 675/675 [==============================] - 1s 987us/step
# 75/75 [==============================] - 0s 1ms/step
# fold --> 10
# 675/675 [==============================] - 1s 986us/step
# 75/75 [==============================] - 0s 1ms/step
# ----------------------------------------
# mean train losses: 0.042509853299707176
# mean train f1 scores: 0.9956543037443428
# mean train accuracies: 0.9920601851851852
# ----------------------------------------
# mean val losses: 0.04534846439957619
# mean val f1 scores: 0.9910481228270935
# mean val accuracies: 0.983625
# ----------------------------------------
# saving graphs...
# 75/75 [==============================] - 0s 1ms/step
# finished saving graphs...
# train 14 finished
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# train 15 initialized...
# hyperparams: dropout: 0.35, learning rate: 0.005
# fold --> 1
# 675/675 [==============================] - 1s 986us/step
# 75/75 [==============================] - 0s 1ms/step
# fold --> 2
# 675/675 [==============================] - 1s 1ms/step
# 75/75 [==============================] - 0s 1ms/step
# fold --> 3
# 675/675 [==============================] - 1s 988us/step
# 75/75 [==============================] - 0s 1ms/step
# fold --> 4
# 675/675 [==============================] - 1s 993us/step
# 75/75 [==============================] - 0s 1ms/step
# fold --> 5
# 675/675 [==============================] - 1s 1ms/step
# 75/75 [==============================] - 0s 1ms/step
# fold --> 6
# 675/675 [==============================] - 1s 1ms/step
# 75/75 [==============================] - 0s 1ms/step
# fold --> 7
# 675/675 [==============================] - 1s 1ms/step
# 75/75 [==============================] - 0s 1ms/step
# fold --> 8
# 675/675 [==============================] - 1s 1ms/step
# 75/75 [==============================] - 0s 1ms/step
# fold --> 9
# 675/675 [==============================] - 1s 991us/step
# 75/75 [==============================] - 0s 1ms/step
# fold --> 10
# 675/675 [==============================] - 1s 959us/step
# 75/75 [==============================] - 0s 1ms/step
# ----------------------------------------
# mean train losses: [0.02192819 0.0148814  0.01212573 0.01004349 0.00832129 0.00921009
#  0.00728569 0.00619606 0.00531088 0.00459928 0.00516859 0.00414359
#  0.00366208 0.0032803  0.00308908 0.0036084  0.00347531 0.00267696
#  0.00270338 0.00237406 0.00267162 0.00239635 0.00223611 0.00208573
#  0.00218365 0.00253412 0.00217583 0.00202856 0.00180625 0.00181337
#  0.00185994 0.00199231 0.00174242 0.00163529 0.00183679 0.00161171
#  0.00177687 0.00171906 0.00166335 0.00158521 0.00174952 0.00164762
#  0.00149116 0.00152742 0.0017433  0.00145873 0.00141187 0.00140199
#  0.00132632]
# mean train f1 scores: 0.997819586273137
# mean train accuracies: 0.9960231481481483
# ----------------------------------------
# mean val losses: [0.0194343  0.01905177 0.02047914 0.02242222 0.02413486 0.00585558
#  0.0066203  0.00749985 0.00854583 0.00975753 0.00317542 0.003965
#  0.00468066 0.00567331 0.00684764 0.00142139 0.00171475 0.00184616
#  0.0021864  0.00263763 0.0016858  0.00216674 0.00247496 0.00279409
#  0.00302225 0.00088069 0.00120664 0.00126441 0.00146294 0.00164459
#  0.0007545  0.00087517 0.0012584  0.00116171 0.00162234 0.00046345
#  0.00052417 0.00057864 0.00068085 0.00041384 0.00052972 0.00057399
#  0.00060353 0.0008122  0.00085798 0.00081872 0.00114066 0.00133122
#  0.00162236]
# mean val f1 scores: 0.992172909672858
# mean val accuracies: 0.9857083333333332
# ----------------------------------------
# saving graphs...
# /home/marcos/anaconda3/envs/test_env/lib/python3.10/site-packages/numpy/core/_methods.py:164: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   arr = asanyarray(a)
# 75/75 [==============================] - 0s 1ms/step
# finished saving graphs...
# train 15 finished
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# train 16 initialized...
# hyperparams: dropout: 0.35, learning rate: 0.01
# fold --> 1
# 675/675 [==============================] - 1s 973us/step
# 75/75 [==============================] - 0s 1ms/step
# fold --> 2
# 675/675 [==============================] - 1s 1ms/step
# 75/75 [==============================] - 0s 1ms/step
# fold --> 3
# 675/675 [==============================] - 1s 1ms/step
# 75/75 [==============================] - 0s 1ms/step
# fold --> 4
# 675/675 [==============================] - 1s 993us/step
# 75/75 [==============================] - 0s 1ms/step
# fold --> 5
# 675/675 [==============================] - 1s 975us/step
# 75/75 [==============================] - 0s 1ms/step
# fold --> 6
# 675/675 [==============================] - 1s 970us/step
# 75/75 [==============================] - 0s 1ms/step
# fold --> 7
# 675/675 [==============================] - 1s 985us/step
# 75/75 [==============================] - 0s 1ms/step
# fold --> 8
# 675/675 [==============================] - 1s 1ms/step
# 75/75 [==============================] - 0s 1ms/step
# fold --> 9
# 675/675 [==============================] - 1s 992us/step
# 75/75 [==============================] - 0s 1ms/step
# fold --> 10
# 675/675 [==============================] - 1s 970us/step
# 75/75 [==============================] - 0s 1ms/step
# ----------------------------------------
# mean train losses: 0.035770132523030046
# mean train f1 scores: 0.9981654284014049
# mean train accuracies: 0.9966574074074075
# ----------------------------------------
# mean val losses: 0.043724689497612414
# mean val f1 scores: 0.9918789754909432
# mean val accuracies: 0.9852083333333332
# ----------------------------------------
# saving graphs...
# 75/75 [==============================] - 0s 1ms/step
# finished saving graphs...
# train 16 finished
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# train 17 initialized...
# hyperparams: dropout: 0.5, learning rate: 0.0005
# fold --> 1
# 675/675 [==============================] - 1s 991us/step
# 75/75 [==============================] - 0s 1ms/step
# fold --> 2
# 675/675 [==============================] - 1s 1ms/step
# 75/75 [==============================] - 0s 998us/step
# fold --> 3
# 675/675 [==============================] - 1s 966us/step
# 75/75 [==============================] - 0s 1ms/step
# fold --> 4
# 675/675 [==============================] - 1s 966us/step
# 75/75 [==============================] - 0s 1ms/step
# fold --> 5
# 675/675 [==============================] - 1s 1ms/step
# 75/75 [==============================] - 0s 1ms/step
# fold --> 6
# 675/675 [==============================] - 1s 1ms/step
# 75/75 [==============================] - 0s 1ms/step
# fold --> 7
# 675/675 [==============================] - 1s 988us/step
# 75/75 [==============================] - 0s 1ms/step
# fold --> 8
# 675/675 [==============================] - 1s 987us/step
# 75/75 [==============================] - 0s 1ms/step
# fold --> 9
# 675/675 [==============================] - 1s 962us/step
# 75/75 [==============================] - 0s 1ms/step
# fold --> 10
# 675/675 [==============================] - 1s 970us/step
# 75/75 [==============================] - 0s 1ms/step
# ----------------------------------------
# mean train losses: 0.07408126346766948
# mean train f1 scores: 0.9920652427083401
# mean train accuracies: 0.985462962962963
# ----------------------------------------
# mean val losses: 0.06849868651479482
# mean val f1 scores: 0.9880815322525969
# mean val accuracies: 0.9781666666666666
# ----------------------------------------
# saving graphs...
# 75/75 [==============================] - 0s 1ms/step
# finished saving graphs...
# train 17 finished
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# train 18 initialized...
# hyperparams: dropout: 0.5, learning rate: 0.001
# fold --> 1
# 675/675 [==============================] - 1s 1ms/step
# 75/75 [==============================] - 0s 1ms/step
# fold --> 2
# 675/675 [==============================] - 1s 971us/step
# 75/75 [==============================] - 0s 1ms/step
# fold --> 3
# 675/675 [==============================] - 1s 1ms/step
# 75/75 [==============================] - 0s 1ms/step
# fold --> 4
# 675/675 [==============================] - 1s 969us/step
# 75/75 [==============================] - 0s 1ms/step
# fold --> 5
# 675/675 [==============================] - 1s 965us/step
# 75/75 [==============================] - 0s 1ms/step
# fold --> 6
# 675/675 [==============================] - 1s 967us/step
# 75/75 [==============================] - 0s 1ms/step
# fold --> 7
# 675/675 [==============================] - 1s 973us/step
# 75/75 [==============================] - 0s 1ms/step
# fold --> 8
# 675/675 [==============================] - 1s 982us/step
# 75/75 [==============================] - 0s 1ms/step
# fold --> 9
# 675/675 [==============================] - 1s 992us/step
# 75/75 [==============================] - 0s 1ms/step
# fold --> 10
# 675/675 [==============================] - 1s 966us/step
# 75/75 [==============================] - 0s 1ms/step
# ----------------------------------------
# mean train losses: 0.054288241863250736
# mean train f1 scores: 0.9941802513033917
# mean train accuracies: 0.9893564814814815
# ----------------------------------------
# mean val losses: 0.051545608155429364
# mean val f1 scores: 0.9906421260901803
# mean val accuracies: 0.9828749999999999
# ----------------------------------------
# saving graphs...
# 75/75 [==============================] - 0s 1ms/step
# finished saving graphs...
# train 18 finished
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# train 19 initialized...
# hyperparams: dropout: 0.5, learning rate: 0.005
# fold --> 1
# 675/675 [==============================] - 1s 969us/step
# 75/75 [==============================] - 0s 1ms/step
# fold --> 2
# 675/675 [==============================] - 1s 966us/step
# 75/75 [==============================] - 0s 1ms/step
# fold --> 3
# 675/675 [==============================] - 1s 978us/step
# 75/75 [==============================] - 0s 1ms/step
# fold --> 4
# 675/675 [==============================] - 1s 976us/step
# 75/75 [==============================] - 0s 1ms/step
# fold --> 5
# 675/675 [==============================] - 1s 1ms/step
# 75/75 [==============================] - 0s 1ms/step
# fold --> 6
# 675/675 [==============================] - 1s 985us/step
# 75/75 [==============================] - 0s 1ms/step
# fold --> 7
# 675/675 [==============================] - 1s 1ms/step
# 75/75 [==============================] - 0s 1ms/step
# fold --> 8
# 675/675 [==============================] - 1s 1ms/step
# 75/75 [==============================] - 0s 1ms/step
# fold --> 9
# 675/675 [==============================] - 1s 970us/step
# 75/75 [==============================] - 0s 1ms/step
# fold --> 10
# 675/675 [==============================] - 1s 966us/step
# 75/75 [==============================] - 0s 1ms/step
# ----------------------------------------
# mean train losses: 0.05075503628700972
# mean train f1 scores: 0.9966346105471355
# mean train accuracies: 0.9938518518518519
# ----------------------------------------
# mean val losses: 0.051086662877351044
# mean val f1 scores: 0.9907363330356155
# mean val accuracies: 0.9830833333333334
# ----------------------------------------
# saving graphs...
# 75/75 [==============================] - 0s 1ms/step
# finished saving graphs...
# train 19 finished
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# train 20 initialized...
# hyperparams: dropout: 0.5, learning rate: 0.01
# fold --> 1
# 675/675 [==============================] - 1s 1ms/step
# 75/75 [==============================] - 0s 1ms/step
# fold --> 2
# 675/675 [==============================] - 1s 1ms/step
# 75/75 [==============================] - 0s 1ms/step
# fold --> 3
# 675/675 [==============================] - 1s 1ms/step
# 75/75 [==============================] - 0s 1ms/step
# fold --> 4
# 675/675 [==============================] - 1s 1ms/step
# 75/75 [==============================] - 0s 1ms/step
# fold --> 5
# 675/675 [==============================] - 1s 1ms/step
# 75/75 [==============================] - 0s 1ms/step
# fold --> 6
# 675/675 [==============================] - 1s 984us/step
# 75/75 [==============================] - 0s 1ms/step
# fold --> 7
# 675/675 [==============================] - 1s 1ms/step
# 75/75 [==============================] - 0s 2ms/step
# fold --> 8
# 675/675 [==============================] - 1s 1ms/step
# 75/75 [==============================] - 0s 1ms/step
# fold --> 9
# 675/675 [==============================] - 1s 1ms/step
# 75/75 [==============================] - 0s 1ms/step
# fold --> 10
# 675/675 [==============================] - 1s 992us/step
# 75/75 [==============================] - 0s 1ms/step
# ----------------------------------------
# mean train losses: 0.06114827647805214
# mean train f1 scores: 0.9954759741300352
# mean train accuracies: 0.9917268518518518
# ----------------------------------------
# mean val losses: 0.05619448449462652
# mean val f1 scores: 0.9889785656423211
# mean val accuracies: 0.9798333333333332
# ----------------------------------------
# saving graphs...
# 75/75 [==============================] - 0s 1ms/step
# finished saving graphs...
# train 20 finished
# --------------------------------------------------------------------------------
