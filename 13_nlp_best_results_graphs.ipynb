# %%
import matplotlib.pyplot as plt

# %%
# Buscape - TFIDF + MLP
f1_score = [0.86, 0.84, 0.83, 0.83, 0.83, 0.85, 0.83, 0.83, 0.86, 0.85, 0.83, 0.83, 0.86, 0.85, 0.84, 0.83, 0.86, 0.86, 0.85, 0.85]
accuracy = [0.85, 0.84, 0.83, 0.83, 0.83, 0.84, 0.83, 0.83, 0.86, 0.85, 0.83, 0.83, 0.86, 0.85, 0.84, 0.83, 0.86, 0.86, 0.84, 0.84]

# Create an array of indices to use as x-axis labels
indices = range(1, len(f1_score) + 1)

plt.figure(figsize=(10, 6))
plt.plot(indices, f1_score, marker='o', label='F1 Score')
plt.plot(indices, accuracy, marker='s', label='Accuracy')
plt.xlabel('Data Point')
plt.ylabel('Score')
plt.title('F1 Score and Accuracy Comparison')
plt.xticks(indices)
plt.legend()
plt.grid(True)
plt.show()
