# %% [markdown]
# <b>INSTITUTO FEDERAL DE GOIÁS<br/>
# PÓS-GRADUAÇÃO EM INTELIGÊNCIA ARTIFICIAL APLICADA<br/></b>
# Disciplina: Processamento de Linguagem Natural  <br/>
# Professor: Daniel Xavier de Sousa <br/>
# Alunos: Wagner Silva, Cleibson, Marcos Rodrigues
#
#
# ---

# %%
import pandas as pd
import numpy as np
import torch

from transformers import AutoTokenizer, AutoModel

from sklearn.model_selection import cross_val_score, train_test_split
from sklearn.model_selection import KFold
from sklearn.metrics import accuracy_score, f1_score

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.optimizers import Adam
from transformers import BertTokenizer, BertModel

import matplotlib.pyplot as plt

# %%
#Dropout: 5%, 15%, 25%, 35%, and 50%
DROPOUT = 0.05

#Learning rate: 5e-4, 1e-3, 5e-3, 1e-2
LEARNING_RATE = 5e-4

# %%
model_name = "bert-base-multilingual-cased"
tokenizer = BertTokenizer.from_pretrained(model_name)
model = BertModel.from_pretrained(model_name)
#tokenizer = AutoTokenizer.from_pretrained("")
#model = AutoModel.from_pretrained("")
# Out:
# Downloading (…)solve/main/vocab.txt: 100%|██████████| 996k/996k [00:00<00:00, 1.98MB/s]
# Downloading (…)okenizer_config.json: 100%|██████████| 29.0/29.0 [00:00<00:00, 104kB/s]
# Downloading (…)lve/main/config.json: 100%|██████████| 625/625 [00:00<00:00, 2.11MB/s]
# Downloading model.safetensors: 100%|██████████| 714M/714M [04:36<00:00, 2.58MB/s]

# %%
df = pd.read_csv('../datasets/buscape_preprocessed_balanced_cleared.csv')

# %%
df.head(3)
# Out:
#                                          review_text  rating
# 0  nao comparia novamente essa marca pois paguei ...       0
# 1  tem uma boa aderencia te da mas agilidades no ...       0
# 2  somente mais um jogo do estilo nada realmente ...       0

# %%
print(f'{df.shape[0]} instancias, {df.shape[1]} classes')
# Out:
# 13620 instancias, 2 classes

# %% [markdown]
# #### Dividindo dataset em dois batchs, 50% cada

# %%
reviews_batch_01, reviews_batch_02, labels_batch_01, labels_batch_02 = train_test_split(df['review_text'], df['rating'], test_size=0.5, random_state=42)

# %%
print(f'batch_01: {reviews_batch_01.shape[0]} instancias')
print(f'batch_02: {reviews_batch_02.shape[0]} instancias')
# Out:
# batch_01: 6810 instancias
# batch_02: 6810 instancias

# %% [markdown]
# #### Quantidade de avaliações positivas e negativas no batch_01

# %%
labels_batch_01.value_counts()
# Out:
# rating
# 1    3419
# 0    3391
# Name: count, dtype: int64

# %%
reviews = reviews_batch_01
labels = labels_batch_01

# %% [markdown]
# #### Tokenização e geração dos embeddings
# - Este processo pode demorar alguns instantes para ser concluído

# %%
embeddings = []
for review in reviews:
    inputs = tokenizer(review, return_tensors="pt", padding=True, truncation=True )
    with torch.no_grad():
        output = model(**inputs)
    embeddings.append(output.last_hidden_state.mean(dim=1).numpy())

# %%
embeddings_array = np.vstack(embeddings)

# %%
print(f'{embeddings_array.shape[0]} embeddings de {embeddings_array.shape[1]} dimensões')
# Out:
# 6810 embeddings de 768 dimensões

# %% [markdown]
# #### Feature based 1

# %%
additional_features = np.array([[len(review.split())] for review in reviews_batch_02])

# %%
print(embeddings_array.shape)
print(additional_features.shape)
# Out:
# (6810, 768)
# (6810, 1)

# %% [markdown]
# #### Combinando embeddings_array e additional_features

# %%
combined_features = np.hstack((embeddings_array, additional_features))

# %% [markdown]
# #### Dividindo dataset treino e teste

# %%
X_train, X_test, y_train, y_test = train_test_split(combined_features, labels, test_size=0.2, random_state=42)

# %%
X_train_tensor = tf.convert_to_tensor(X_train, dtype=tf.float32)
y_train_tensor = tf.convert_to_tensor(y_train, dtype=tf.float32)

# %%
X_test_tensor = tf.convert_to_tensor(X_test, dtype=tf.float32)
y_test_tensor = tf.convert_to_tensor(y_test, dtype=tf.float32)

# %% [markdown]
# #### Arquitetura rede neural MLP

# %%
model = Sequential([
    Dense(24, activation='relu', input_dim=X_train_tensor.shape[1]),
    Dropout(DROPOUT),
    Dense(1, activation='sigmoid')
])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 24)                18480
#
#  dropout (Dropout)           (None, 24)                0
#
#  dense_1 (Dense)             (None, 1)                 25
#
# =================================================================
# Total params: 18,505
# Trainable params: 18,505
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer=Adam(learning_rate=LEARNING_RATE), loss='binary_crossentropy', metrics=['accuracy'])

# %% [markdown]
# #### Cross-validation

# %%
num_folds = 10
kf = KFold(n_splits=num_folds, shuffle=True, random_state=42)

# %% [markdown]
# #### Ajustando path para salvar os pesos

# %%
CHECKPOINT=ModelCheckpoint(filepath='../weights/tlm_peq_mult_weights.hdf5', verbose=1, save_best_only=True)
EARLY_STOP = EarlyStopping(monitor='val_loss', patience=3)
CALLBACKS = [CHECKPOINT, EARLY_STOP]

# %% [markdown]
# #### Treinamento do modelo

# %%
fold = 0

fold_accuracies = []
fold_f1_scores = []

train_loss_history = []
train_accuracy_history = []
for train_indices, val_indices in kf.split(combined_features):
    fold+=1
    print(f'fold = {fold}')
    X_train_fold = combined_features[train_indices]
    y_train_fold = np.array(labels)[train_indices]
    
    X_val_fold = combined_features[val_indices]
    y_val_fold = np.array(labels)[val_indices]
    
    X_train_fold_tensor = tf.convert_to_tensor(X_train_fold, dtype=tf.float32)
    y_train_fold_tensor = tf.convert_to_tensor(y_train_fold, dtype=tf.float32)
    
    X_val_fold_tensor = tf.convert_to_tensor(X_val_fold, dtype=tf.float32)
    y_val_fold_tensor = tf.convert_to_tensor(y_val_fold, dtype=tf.float32)
    
    model_history = model.fit(
        X_train_fold_tensor, 
        y_train_fold_tensor, 
        epochs=10, 
        batch_size=32, 
        verbose=1,
        validation_data=(X_val_fold_tensor, y_val_fold_tensor),
        callbacks=CALLBACKS,
    )
    
    y_pred_val = model.predict(X_val_fold_tensor)
    y_pred_val_binary = np.round(y_pred_val)
    
    fold_accuracy = accuracy_score(y_val_fold, y_pred_val_binary)
    fold_accuracies.append(fold_accuracy)
    
    fold_f1_score = f1_score(y_val_fold, y_pred_val_binary)
    fold_f1_scores.append(fold_f1_score)
    
    train_loss_history.append(model_history.history['loss'])
    train_accuracy_history.append(model_history.history['accuracy'])
    
print("Cross-Validation Accuracies:", fold_accuracies)
print("Cross-Validation Scores:", fold_f1_scores)
print("Media Accuracy:", np.mean(fold_accuracies))
print("Media f1 score:", np.mean(fold_f1_scores))

plt.figure(figsize=(10, 6))
for fold_num, fold_loss in enumerate(train_loss_history):
    plt.plot(fold_loss, label=f'Fold {fold_num+1}')
plt.xlabel('Epoch')
plt.ylabel('Training Loss')
plt.title('Training Loss per Epoch for Each Fold')
plt.legend()
plt.show()

plt.figure(figsize=(10, 6))
for fold_num, fold_accuracy in enumerate(train_accuracy_history):
    plt.plot(fold_accuracy, label=f'Fold {fold_num+1}')
plt.xlabel('Epoch')
plt.ylabel('Training Accuracy')
plt.title('Training Accuracy per Epoch for Each Fold')
plt.legend()
plt.show()
# Out:
# fold = 1
# Epoch 1/10
# 156/192 [=======================>......] - ETA: 0s - loss: 0.3520 - accuracy: 0.8474
# Epoch 1: val_loss improved from inf to 0.35569, saving model to ../weights/tlm_peq_mult_weights.hdf5
# 192/192 [==============================] - 0s 2ms/step - loss: 0.3540 - accuracy: 0.8474 - val_loss: 0.3557 - val_accuracy: 0.8546
# Epoch 2/10
# 192/192 [==============================] - ETA: 0s - loss: 0.3542 - accuracy: 0.8460
# Epoch 2: val_loss improved from 0.35569 to 0.35431, saving model to ../weights/tlm_peq_mult_weights.hdf5
# 192/192 [==============================] - 0s 2ms/step - loss: 0.3542 - accuracy: 0.8460 - val_loss: 0.3543 - val_accuracy: 0.8473
# Epoch 3/10
# 152/192 [======================>.......] - ETA: 0s - loss: 0.3514 - accuracy: 0.8450
# Epoch 3: val_loss did not improve from 0.35431
# 192/192 [==============================] - 0s 2ms/step - loss: 0.3500 - accuracy: 0.8476 - val_loss: 0.3598 - val_accuracy: 0.8517
# Epoch 4/10
# 179/192 [==========================>...] - ETA: 0s - loss: 0.3428 - accuracy: 0.8499
# Epoch 4: val_loss did not improve from 0.35431
# 192/192 [==============================] - 0s 2ms/step - loss: 0.3444 - accuracy: 0.8486 - val_loss: 0.3632 - val_accuracy: 0.8370
# Epoch 5/10
# 184/192 [===========================>..] - ETA: 0s - loss: 0.3455 - accuracy: 0.8494
# Epoch 5: val_loss did not improve from 0.35431
# 192/192 [==============================] - 0s 2ms/step - loss: 0.3453 - accuracy: 0.8507 - val_loss: 0.3651 - val_accuracy: 0.8443
# 22/22 [==============================] - 0s 962us/step
# fold = 2
# Epoch 1/10
# 156/192 [=======================>......] - ETA: 0s - loss: 0.3414 - accuracy: 0.8534
# Epoch 1: val_loss improved from 0.35431 to 0.33610, saving model to ../weights/tlm_peq_mult_weights.hdf5
# 192/192 [==============================] - 0s 2ms/step - loss: 0.3449 - accuracy: 0.8510 - val_loss: 0.3361 - val_accuracy: 0.8532
# Epoch 2/10
# 154/192 [=======================>......] - ETA: 0s - loss: 0.3399 - accuracy: 0.8584
# Epoch 2: val_loss did not improve from 0.33610
# 192/192 [==============================] - 0s 2ms/step - loss: 0.3404 - accuracy: 0.8577 - val_loss: 0.3561 - val_accuracy: 0.8370
# Epoch 3/10
# 156/192 [=======================>......] - ETA: 0s - loss: 0.3400 - accuracy: 0.8582
# Epoch 3: val_loss did not improve from 0.33610
# 192/192 [==============================] - 0s 1ms/step - loss: 0.3402 - accuracy: 0.8543 - val_loss: 0.3451 - val_accuracy: 0.8473
# Epoch 4/10
# 192/192 [==============================] - ETA: 0s - loss: 0.3343 - accuracy: 0.8616
# Epoch 4: val_loss did not improve from 0.33610
# 192/192 [==============================] - 0s 2ms/step - loss: 0.3343 - accuracy: 0.8616 - val_loss: 0.3773 - val_accuracy: 0.8341
# 22/22 [==============================] - 0s 871us/step
# fold = 3
# Epoch 1/10
# 192/192 [==============================] - ETA: 0s - loss: 0.3329 - accuracy: 0.8587
# Epoch 1: val_loss did not improve from 0.33610
# 192/192 [==============================] - 0s 2ms/step - loss: 0.3329 - accuracy: 0.8587 - val_loss: 0.3395 - val_accuracy: 0.8605
# Epoch 2/10
# 174/192 [==========================>...] - ETA: 0s - loss: 0.3278 - accuracy: 0.8561
# Epoch 2: val_loss did not improve from 0.33610
# 192/192 [==============================] - 0s 2ms/step - loss: 0.3278 - accuracy: 0.8572 - val_loss: 0.3380 - val_accuracy: 0.8693
# Epoch 3/10
# 175/192 [==========================>...] - ETA: 0s - loss: 0.3241 - accuracy: 0.8648
# Epoch 3: val_loss did not improve from 0.33610
# 192/192 [==============================] - 0s 2ms/step - loss: 0.3231 - accuracy: 0.8652 - val_loss: 0.3546 - val_accuracy: 0.8473
# Epoch 4/10
# 171/192 [=========================>....] - ETA: 0s - loss: 0.3176 - accuracy: 0.8637
# Epoch 4: val_loss did not improve from 0.33610
# 192/192 [==============================] - 0s 2ms/step - loss: 0.3215 - accuracy: 0.8628 - val_loss: 0.3664 - val_accuracy: 0.8473
# Epoch 5/10
# 168/192 [=========================>....] - ETA: 0s - loss: 0.3192 - accuracy: 0.8614
# Epoch 5: val_loss did not improve from 0.33610
# 192/192 [==============================] - 0s 2ms/step - loss: 0.
# 192/192 [==============================] - 0s 2ms/step - loss: 0.2598 - accuracy: 0.8923 - val_loss: 0.2684 - val_accuracy: 0.8987
# Epoch 2/10
# 182/192 [===========================>..] - ETA: 0s - loss: 0.2578 - accuracy: 0.8951
# Epoch 2: val_loss improved from 0.23630 to 0.23587, saving model to ../weights/tlm_peq_mult_weights.hdf5
# 192/192 [==============================] - 0s 2ms/step - loss: 0.2550 - accuracy: 0.8969 - val_loss: 0.2359 - val_accuracy: 0.9104
# Epoch 3/10
# 176/192 [==========================>...] - ETA: 0s - loss: 0.2492 - accuracy: 0.8993
# Epoch 3: val_loss did not improve from 0.23587
# 192/192 [==============================] - 0s 2ms/step - loss: 0.2487 - accuracy: 0.9000 - val_loss: 0.2395 - val_accuracy: 0.9075
# Epoch 4/10
# 190/192 [============================>.] - ETA: 0s - loss: 0.2460 - accuracy: 0.9016
# Epoch 4: val_loss did not improve from 0.23587
# 192/192 [==============================] - 0s 2ms/step - loss: 0.2457 - accuracy: 0.9019 - val_loss: 0.2452 - val_accuracy: 0.9060
# Epoch 5/10
# 184/192 [===========================>..] - ETA: 0s - loss: 0.2455 - accuracy: 0.9029
# Epoch 5: val_loss did not improve from 0.23587
# 192/192 [==============================] - 0s 2ms/step - loss: 0.2448 - accuracy: 0.9031 - val_loss: 0.2641 - val_accuracy: 0.8781
# 22/22 [==============================] - 0s 1ms/step
# Cross-Validation Accuracies: [0.8443465491923642, 0.8340675477239354, 0.8325991189427313, 0.8311306901615272, 0.8707782672540382, 0.8516886930983847, 0.8898678414096917, 0.9045521292217328, 0.8928046989720999, 0.8781204111600588]
# Cross-Validation Scores: [0.852367688022284, 0.8220472440944881, 0.8475935828877005, 0.8321167883211678, 0.8742857142857144, 0.8669301712779973, 0.8911465892597968, 0.8989113530326593, 0.8995873452544704, 0.8826025459688827]
# Media Accuracy: 0.8629955947136564
# Media f1 score: 0.8667589022405162

# %%
test_loss, test_accuracy = model.evaluate(X_test_tensor, y_test_tensor)
# Out:
# 43/43 [==============================] - 0s 1ms/step - loss: 0.2125 - accuracy: 0.9104

# %%
def load_weights_from_hdf5(model, weight_path):
    model.load_weights(weight_path)
    return model

# %%
tlm_gran_weights_path = '../weights/tlm_peq_mult_weights.hdf5'
model = load_weights_from_hdf5(model, tlm_gran_weights_path)

# %%
fold = 0

fold_accuracies = []
fold_f1_scores = []

train_loss_history = []
train_accuracy_history = []
for train_indices, val_indices in kf.split(combined_features):
    fold+=1
    print(f'fold = {fold}')
    X_train_fold = combined_features[train_indices]
    y_train_fold = np.array(labels)[train_indices]
    
    X_val_fold = combined_features[val_indices]
    y_val_fold = np.array(labels)[val_indices]
    
    # Convertendo dados treino em tensores
    X_train_fold_tensor = tf.convert_to_tensor(X_train_fold, dtype=tf.float32)
    y_train_fold_tensor = tf.convert_to_tensor(y_train_fold, dtype=tf.float32)
    
    # Convertendo dados de validacao em tensores
    X_val_fold_tensor = tf.convert_to_tensor(X_val_fold, dtype=tf.float32)
    y_val_fold_tensor = tf.convert_to_tensor(y_val_fold, dtype=tf.float32)
    
    model_history = model.fit(
        X_train_fold_tensor, 
        y_train_fold_tensor, 
        epochs=10, 
        batch_size=32, 
        verbose=1,
        validation_data=(X_val_fold_tensor, y_val_fold_tensor),
        callbacks=CALLBACKS
    )
    
    y_pred_val = model.predict(X_val_fold_tensor)
    y_pred_val_binary = np.round(y_pred_val)
    
    fold_accuracy = accuracy_score(y_val_fold, y_pred_val_binary)
    fold_accuracies.append(fold_accuracy)
    
    fold_f1_score = f1_score(y_val_fold, y_pred_val_binary)
    fold_f1_scores.append(fold_f1_score)
    
    train_loss_history.append(model_history.history['loss'])
    train_accuracy_history.append(model_history.history['accuracy'])
    
print("Cross-Validation Accuracies:", fold_accuracies)
print("Cross-Validation Scores:", fold_f1_scores)
print("Media Accuracy:", np.mean(fold_accuracies))
print("Media f1 score:", np.mean(fold_f1_scores))

plt.figure(figsize=(10, 6))
for fold_num, fold_loss in enumerate(train_loss_history):
    plt.plot(fold_loss, label=f'Fold {fold_num+1}')
plt.xlabel('Epoch')
plt.ylabel('Training Loss')
plt.title('Training Loss per Epoch for Each Fold')
plt.legend()
plt.show()

plt.figure(figsize=(10, 6))
for fold_num, fold_accuracy in enumerate(train_accuracy_history):
    plt.plot(fold_accuracy, label=f'Fold {fold_num+1}')
plt.xlabel('Epoch')
plt.ylabel('Training Accuracy')
plt.title('Training Accuracy per Epoch for Each Fold')
plt.legend()
plt.show()
# Out:
# fold = 1
# Epoch 1/10
# 165/192 [========================>.....] - ETA: 0s - loss: 0.2516 - accuracy: 0.8981
# Epoch 1: val_loss improved from 0.23587 to 0.22476, saving model to ../weights/tlm_peq_mult_weights.hdf5
# 192/192 [==============================] - 0s 2ms/step - loss: 0.2530 - accuracy: 0.8975 - val_loss: 0.2248 - val_accuracy: 0.9280
# Epoch 2/10
# 160/192 [========================>.....] - ETA: 0s - loss: 0.2522 - accuracy: 0.8967
# Epoch 2: val_loss did not improve from 0.22476
# 192/192 [==============================] - 0s 1ms/step - loss: 0.2502 - accuracy: 0.8979 - val_loss: 0.2276 - val_accuracy: 0.9163
# Epoch 3/10
# 156/192 [=======================>......] - ETA: 0s - loss: 0.2458 - accuracy: 0.9026
# Epoch 3: val_loss did not improve from 0.22476
# 192/192 [==============================] - 0s 1ms/step - loss: 0.2452 - accuracy: 0.9028 - val_loss: 0.2288 - val_accuracy: 0.9104
# Epoch 4/10
# 160/192 [========================>.....] - ETA: 0s - loss: 0.2399 - accuracy: 0.9053
# Epoch 4: val_loss did not improve from 0.22476
# 192/192 [==============================] - 0s 2ms/step - loss: 0.2409 - accuracy: 0.9041 - val_loss: 0.2420 - val_accuracy: 0.9090
# 22/22 [==============================] - 0s 778us/step
# fold = 2
# Epoch 1/10
# 165/192 [========================>.....] - ETA: 0s - loss: 0.2407 - accuracy: 0.9072
# Epoch 1: val_loss improved from 0.22476 to 0.22385, saving model to ../weights/tlm_peq_mult_weights.hdf5
# 192/192 [==============================] - 0s 2ms/step - loss: 0.2392 - accuracy: 0.9083 - val_loss: 0.2239 - val_accuracy: 0.9090
# Epoch 2/10
# 182/192 [===========================>..] - ETA: 0s - loss: 0.2354 - accuracy: 0.9090
# Epoch 2: val_loss improved from 0.22385 to 0.22094, saving model to ../weights/tlm_peq_mult_weights.hdf5
# 192/192 [==============================] - 0s 2ms/step - loss: 0.2338 - accuracy: 0.9103 - val_loss: 0.2209 - val_accuracy: 0.9090
# Epoch 3/10
# 182/192 [===========================>..] - ETA: 0s - loss: 0.2355 - accuracy: 0.9111
# Epoch 3: val_loss did not improve from 0.22094
# 192/192 [==============================] - 0s 2ms/step - loss: 0.2362 - accuracy: 0.9091 - val_loss: 0.2231 - val_accuracy: 0.9119
# Epoch 4/10
# 163/192 [========================>.....] - ETA: 0s - loss: 0.2363 - accuracy: 0.9053
# Epoch 4: val_loss did not improve from 0.22094
# 192/192 [==============================] - 0s 1ms/step - loss: 0.2347 - accuracy: 0.9063 - val_loss: 0.2251 - val_accuracy: 0.9119
# Epoch 5/10
# 174/192 [==========================>...] - ETA: 0s - loss: 0.2283 - accuracy: 0.9104
# Epoch 5: val_loss did not improve from 0.22094
# 192/192 [==============================] - 0s 2ms/step - loss: 0.2302 - accuracy: 0.9085 - val_loss: 0.2372 - val_accuracy: 0.9046
# 22/22 [==============================] - 0s 951us/step
# fold = 3
# Epoch 1/10
# 157/192 [=======================>......] - ETA: 0s - loss: 0.2327 - accuracy: 0.9070
# Epoch 1: val_loss did not improve from 0.22094
# 192/192 [==============================] - 0s 2ms/step - loss: 0.2339 - accuracy: 0.9078 - val_loss: 0.2224 - val_accuracy: 0.9046
# Epoch 2/10
# 158/192 [=======================>......] - ETA: 0s - loss: 0.2313 - accuracy: 0.9092
# Epoch 2: val_loss did not improve from 0.22094
# 192/192 [==============================] - 0s 1ms/step - loss: 0.2283 - accuracy: 0.9104 - val_loss: 0.2373 - val_accuracy: 0.9104
# Epoch 3/10
# 155/192 [=======================>......] - ETA: 0s - loss: 0.2220 - accuracy: 0.9125
# Epoch 3: val_loss did not improve from 0.22094
# 192/192 [==============================] - 0s 1ms/step - loss: 0.2203 - accuracy: 0.9145 - val_loss: 0.2398 - val_accuracy: 0.9046
# Epoch 4/10
# 191/192 [============================>.] - ETA: 0s - loss: 0.2223 - accuracy: 0.9131
# Epoch 4: val_loss did not improve from 0.22094
# 192/192 [==============================] - 0s 2ms/step - loss: 0.2224 - accuracy: 0.9130 - val_loss: 0.2425 - val_accuracy: 0.8987
# 22/22 [==============================] - 0s 821us/step
# fold = 4
# Epoch 1/10
# 156/192 [=======================>......] - ETA: 0s - loss: 0.2347 - accuracy: 0.9091
# Epoch 1: val_loss did not improve from 0.22094
# 192/192 [==============================] - 0s 2ms/step - loss: 0.2322 - accuracy: 0.9080 - val_loss: 0.2320 - val_accuracy: 0.9090
# Epoch 2/10
# 192/192 [==============================] - ETA: 0s - loss: 0.2165 - accuracy: 0.9181
# Epoch 2: val_loss did not improve from 0.22094
# 192/192 [==============================] - 0s 2ms/step - loss: 0.2165 - accuracy: 0.9181 - val_loss: 0.2419 - val_accuracy: 0.9016
# Epoch 3/10
# 188/192 [============================>.] - ETA: 0s - loss: 0.2150 - accuracy: 0.9171
# Epoch 3: val_loss did not improve from 0.22094
# 192/192 [==============================] - 0s 2ms/step - loss: 0.2160 - accuracy: 0.9161 - val_loss: 0.2404 - val_accuracy: 0.9090
# Epoch 4/10
# 180/192 [===========================>..] - ETA: 0s - loss: 0.2129 - accuracy: 0.9179
# Epoch 4: val_loss did not improve from 0.22094
# 192/192 [==============================] - 0s 2ms/step - loss: 0.2143 - accuracy: 0.9163 - val_loss: 0.2428 - val_accuracy: 0.8987
# 22/22 [==============================] - 0s 1ms/step
# fold = 5
# Epoch 1/10
# 170/192 [=========================>....] - ETA: 0s - loss: 0.2142 - accuracy: 0.9176
# Epoch 1: val_loss improved from 0.22094 to 0.18483, saving model to ../weights/tlm_peq_mult_weights.hdf5
# 192/192 [==============================] - 0s 2ms/step - loss: 0.2166 - accuracy: 0.9160 - val_loss: 0.1848 - val_accuracy: 0.9325
# Epoch 2/10
# 189/192 [============================>.] - ETA: 0s - loss: 0.2153 - accuracy: 0.9195
# Epoch 2: val_loss did not improve from 0.18483
# 192/192 [==============================] - 0s 2ms/step - loss: 0.2156 - accuracy: 0.9191 - val_loss: 0.2081 - val_accuracy: 0.9178
# Epoch 3/10
# 175/192 [==========================>...] - ETA: 0s - loss: 0.2166 - accuracy: 0.9180
# Epoch 3: val_loss did not improve from 0.18483
# 192/192 [==============================] - 0s 2ms/step - loss: 0.2151 - accuracy: 0.9187 - val_loss: 0.1936 - val_accuracy: 0.9163
# Epoch 4/10
# 180/192 [===========================>..] - ETA: 0s - loss: 0.2126 - accuracy: 0.9168
# Epoch 4: val_loss did not improve from 0.18483
# 192/192 [==============================] - 0s 2ms/step - loss: 0.2136 - accuracy: 0.9170 - val_loss: 0.1943 - val_accuracy: 0.9295
# 22/22 [==============================] - 0s 1ms/step
# fold = 6
# Epoch 1/10
# 169/192 [=========================>....] - ETA: 0s - loss: 0.2092 - accuracy: 0.9222
# Epoch 1: val_loss improved from 0.18483 to 0.18081, saving model to ../weights/tlm_peq_mult_weights.hdf5
# 192/192 [==============================] - 0s 2ms/step - loss: 0.2080 - accuracy: 0.9220 - val_loss: 0.1808 - val_accuracy: 0.9310
# Epoch 2/10
# 178/192 [==========================>...] - ETA: 0s - loss: 0.2062 - accuracy: 0.9215
# Epoch 2: val_loss improved from 0.18081 to 0.17196, saving model to ../weights/tlm_peq_mult_weights.hdf5
# 192/192 [==============================] - 0s 2ms/step - loss: 0.2063 - accuracy: 0.9215 - val_loss: 0.1720 - val_accuracy: 0.9383
# Epoch 3/10
# 167/192 [=========================>....] - ETA: 0s - loss: 0.2050 - accuracy: 0.9233
# Epoch 3: val_loss did not improve from 0.17196
# 192/192 [==============================] - 0s 2ms/step - loss: 0.
# 192/192 [==============================] - 0s 2ms/step - loss: 0.1807 - accuracy: 0.9329 - val_loss: 0.1745 - val_accuracy: 0.9383
# Epoch 3/10
# 183/192 [===========================>..] - ETA: 0s - loss: 0.1793 - accuracy: 0.9331
# Epoch 3: val_loss improved from 0.17007 to 0.16685, saving model to ../weights/tlm_peq_mult_weights.hdf5
# 192/192 [==============================] - 0s 2ms/step - loss: 0.1806 - accuracy: 0.9321 - val_loss: 0.1668 - val_accuracy: 0.9383
# Epoch 4/10
# 188/192 [============================>.] - ETA: 0s - loss: 0.1808 - accuracy: 0.9335
# Epoch 4: val_loss did not improve from 0.16685
# 192/192 [==============================] - 0s 2ms/step - loss: 0.1812 - accuracy: 0.9331 - val_loss: 0.2001 - val_accuracy: 0.9310
# Epoch 5/10
# 181/192 [===========================>..] - ETA: 0s - loss: 0.1716 - accuracy: 0.9370
# Epoch 5: val_loss did not improve from 0.16685
# 192/192 [==============================] - 0s 2ms/step - loss: 0.1718 - accuracy: 0.9367 - val_loss: 0.1892 - val_accuracy: 0.9236
# Epoch 6/10
# 190/192 [============================>.] - ETA: 0s - loss: 0.1723 - accuracy: 0.9363
# Epoch 6: val_loss did not improve from 0.16685
# 192/192 [==============================] - 0s 2ms/step - loss: 0.1722 - accuracy: 0.9365 - val_loss: 0.2081 - val_accuracy: 0.9295
# 22/22 [==============================] - 0s 1ms/step
# fold = 10
# Epoch 1/10
# 186/192 [============================>.] - ETA: 0s - loss: 0.1823 - accuracy: 0.9309
# Epoch 1: val_loss improved from 0.16685 to 0.16668, saving model to ../weights/tlm_peq_mult_weights.hdf5
# 192/192 [==============================] - 0s 2ms/step - loss: 0.1823 - accuracy: 0.9313 - val_loss: 0.1667 - val_accuracy: 0.9427
# Epoch 2/10
# 187/192 [============================>.] - ETA: 0s - loss: 0.1734 - accuracy: 0.9372
# Epoch 2: val_loss improved from 0.16668 to 0.15337, saving model to ../weights/tlm_peq_mult_weights.hdf5
# 192/192 [==============================] - 0s 2ms/step - loss: 0.1734 - accuracy: 0.9369 - val_loss: 0.1534 - val_accuracy: 0.9501
# Epoch 3/10
# 188/192 [============================>.] - ETA: 0s - loss: 0.1648 - accuracy: 0.9393
# Epoch 3: val_loss did not improve from 0.15337
# 192/192 [==============================] - 0s 2ms/step - loss: 0.1647 - accuracy: 0.9391 - val_loss: 0.1584 - val_accuracy: 0.9545
# Epoch 4/10
# 187/192 [============================>.] - ETA: 0s - loss: 0.1660 - accuracy: 0.9415
# Epoch 4: val_loss did not improve from 0.15337
# 192/192 [==============================] - 0s 2ms/step - loss: 0.1657 - accuracy: 0.9416 - val_loss: 0.1638 - val_accuracy: 0.9427
# Epoch 5/10
# 154/192 [=======================>......] - ETA: 0s - loss: 0.1627 - accuracy: 0.9422
# Epoch 5: val_loss did not improve from 0.15337
# 192/192 [==============================] - 0s 2ms/step - loss: 0.1639 - accuracy: 0.9409 - val_loss: 0.1708 - val_accuracy: 0.9413
# 22/22 [==============================] - 0s 851us/step
# Cross-Validation Accuracies: [0.908957415565345, 0.9045521292217328, 0.8986784140969163, 0.8986784140969163, 0.9295154185022027, 0.933920704845815, 0.9265785609397944, 0.9192364170337739, 0.9295154185022027, 0.9412628487518355]
# Cross-Validation Scores: [0.913649025069638, 0.9083215796897038, 0.8989751098096632, 0.9010043041606886, 0.9337016574585636, 0.9356223175965666, 0.926470588235294, 0.9131121642969985, 0.9296187683284458, 0.9393939393939394]
# Media Accuracy: 0.9190895741556535
# Media f1 score: 0.9199869454039501

# %%
test_loss, test_accuracy = model.evaluate(X_test_tensor, y_test_tensor)
# Out:
# 43/43 [==============================] - 0s 947us/step - loss: 0.1241 - accuracy: 0.9662
